# %%
import pandas as pd
import numpy as np
from pythainlp import word_tokenize
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix
# import joblib
# import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
import json
import glob

from pythainlp.corpus import thai_stopwords

# %%
file_pattern = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/TripAdvisor_reviews_TH.csv')

# %%
file_pattern

# %%
file_pattern = '../dataset/reviews/TripAdvisor_reviews_TH_Set-*.json'
files = glob.glob(file_pattern)

# Step 2: Initialize an empty list to store the combined data
combined_reviews_data = []

# Step 3: Load each file and concatenate the contents
for file in files:
    with open(file, 'r') as f:
        data = json.load(f)
        combined_reviews_data.extend(data)

# %%
combined_reviews_data
# Out:
# [{'2209612': [{'id': 922231809,
#     'lang': 'th',
#     'location_id': 2209612,
#     'published_date': '2023-10-21T01:18:50Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d2209612-r922231809-Reviews-Wat_Ratchabophit-Bangkok.html?m=66827#review922231809',
#     'text': 'เป็นวัดที่สร้างขึ้นในรัชกาลที่ 5 \nพระบาทสมเด็จพระจุลจอมเกล้าเจ้าอยู่หัว\nมีสถาปัตยกรรมไทยผสมกับกอธิก\nมีพระประธานนามว่า พระพุทธอังคีรส\nมีสร้อยนามว่า สถิตมหาสีมาราม',
#     'title': 'วัดราชบพิตร สถิตมหาสีมาราม',
#     'trip_type': 'ครอบครัว',
#     'travel_date': '2023-10-31',
#     'user': {'username': 'maxzerk',
#      'user_location': {'id': '293916', 'name': 'Bangkok'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/2a/a2/f5/e4/caption.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/2a/a2/f5/e4/caption.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/2a/a2/f5/e4/caption.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-s/2a/a2/f5/e4/caption.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-m/1280/2a/a2/f5/e4/caption.jpg'}},
#     'subratings': {}},
#    {'id': 777982512,
#     'lang': 'th',
#     'location_id': 2209612,
#     'published_date': '2020-11-27T02:16:31Z',
#     'rating': 5,
#     'helpful_votes': 18,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d2209612-r777982512-Reviews-Wat_Ratchabophit-Bangkok.html?m=66827#review777982512',
#     'text': 'ตั้งอยู่ด้านทิศตะวันตกของวัด มีประตูเข้าตรงทางขึ้นด้านหลังพระเจดีย์ของวัด ภายในบรรจุพระอัฐิ พระสรีรางคาร พระอังคาร และอังคารของ พระมเหสี พระราชชายา เจ้าจอมมารดา และพระราชโอรส พระราชธิดา ในพระบาทสมเด็จพระจุลจอมเกล้าเจ้าอยู่หัว รัชกาลที่ ๕ เพื่อให้ลูกได้อยู่รวมกับแม่หรืออย่างน้อยในบ้านของแม่ ',
#     'title': 'ชมสุสานหลวง',
#     'trip_type': 'เดินทางกับเพื่อน',
#     'travel_date': '2020-11-30',
#     'user': {'username': 'kant_setpakdee',
#      'user_location': {'id': '293916', 'name': 'Bangkok'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/19/f1/84/7c/caption.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/19/f1/84/7c/caption.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/19/f1/84/7c/caption.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-s/19/f1/84/7c/caption.jpg'}},
#     'subratings': {}},
#    {'id': 738367222,
#     'lang': 'th',
#     'location_id': 2209612,
#     'published_date': '2020-01-10T23:21:53Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d2209612-r738367222-Reviews-Wat_Ratchabophit-Bangkok.html?m=66827#review738367222',
#     'text': 'วันนี้เป็นที่พำนักของพระสังฆราชองค์ใหม่ ตอนไปกำลังปรัยปรุงอุโบสถอยู่ แต่ด้านหน้าอุโบสถจะมีรูปปั้นร.5 ',
#     'title': 'ไหว้พระ',
#     'trip_type': 'คู่รัก',
#     'travel_date': '2019-12-31',
#     'user': {'username': 'BestHealthiness',
#      'user_location': {'id': '293916', 'name': 'Bangkok'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/15/ad/6c/5c/besthealthiness.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/15/ad/6c/5c/besthealthiness.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/15/ad/6c/5c/besthealthiness.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-o/15/ad/6c/5c/besthealthiness.jpg'}},
#     'subratings': {}},
#    {'id': 737450116,
#     'lang': 'th',
#     'location_id': 2209612,
#     'published_date': '2020-01-06T22:31:39Z',
#     'rating': 5,
#     'helpful_votes': 2,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d2209612-r737450116-Reviews-Wat_Ratchabophit-Bangkok.html?m=66827#review737450116',
#     'text': 'วันนี้เป็นบุญของครอบครัวเราแท้ๆมีโอกาส ได้เข้าเฝ้ากราบสักการะ สมเด็จพระสังฆราช\nปลื้มปิติ เปี่ยมสุข ด้วยพร ที่พระองค์ให้มากับพวกเรา\nขอให้บังเกิด กับ กัลยณมิตรและครอบครัวของพวกเราทุกคนเถิด',
#     'title': 'กราบสักการะ สมเด็จพระสังฆราช',
#     'trip_type': 'NONE',
#     'travel_date': '2019-12-31',
#     'user': {'username': 'hotbee2099',
#      'user_location': {'id': '293916', 'name': 'Bangkok'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/0d/bc/e4/b3/hotbee2099.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/0d/bc/e4/b3/hotbee2099.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/0d/bc/e4/b3/hotbee2099.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-s/0d/bc/e4/b3/hotbee2099.jpg'}},
#     'subratings': {}},
#    {'id': 690288478,
#     'lang': 'th',
#     'location_id': 2209612,
#     'published_date': '2019-07-17T05:44:19Z',
#     'rating': 4,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s4.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d2209612-r690288478-Reviews-Wat_Ratchabophit-Bangkok.html?m=66827#review690288478',
#     'text': 'พอดีมาแถว ถ.เฟื่องนครเลยได้แวะมาวัดนี้ ตอนกลางวันคนไม่เยอะเท่าไหร่ มีให้ทำบุญรับดอกไม้ธูปเทียน ชอบที่เทียนของวัดนี้ทำเชิงเทียนสวยงามกันน้ำตาเทียนหยดใส่มือ มีแจกน้ำเปล่าขวดเล็กฟรีสำหรับคนที่เดินทางมาที่วัดด้วย',
#     'title': 'วัดราชบพิธ',
#     'trip_type': 'ครอบครัว',
#     'travel_date': '2019-07-31',
#     'user': {'username': 'SweetyLollipop',
#      'user_location': {'id': '293916', 'name': 'Bangkok'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/12/b7/08/32/sweetylollipop.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/12/b7/08/32/sweetylollipop.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-o/12/b7/08/32/sweetylollipop.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-s/12/b7/08/32/sweetylollipop.jpg'}},
#     'subratings': {}}]},
#  {'2273363': [{'id': 774819098,
#     'lang': 'th',
#     'location_id': 2273363,
#     'published_date': '2020-10-19T00:27:40Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d2273363-r774819098-Reviews-Wat_Rajapradit_Sathitmahasimaram_Rajaworavihara-Bangkok.html?m=66827#review774819098',
#     'text': 'วัดไทยที่ถูกสร้างในรัชสมัย ร.๔ แม้เนื้อที่จะน้อย แต่ทุกตารางการใช้สอยกลับทำได้อย่างลงตัว มีกำแพงรายล้อมโบสถ์ มีสถูปเจดีย์ รูปปั้นจำลองสมเด็จพระสังฆราชสาอีกด้วย ',
#     'title': 'วัดสวยและขลังมาก',
#     'trip_type': 'เดินทางคนเดียว',
#     'travel_date': '2020-10-31',
#     'user': {'username': 'POPPULAR05',
#      'user_location': {'id': '293916', 'name': 'Bangkok'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1c/32/1b/e4/avatar.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1c/32/1b/e4/avatar.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1c/32/1b/e4/avatar.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-s/1c/32/1b/e4/avatar.jpg'}},
#     'subratings': {}},
#    {'id': 709123251,
#     'lang': 'th',
#     'location_id': 2273363,
#     'published_date': '2019-09-12T11:13:49Z',
#     'rating': 4,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s4.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d2273363-r709123251-Reviews-Wat_Rajapradit_Sathitmahasimaram_Rajaworavihara-Bangkok.html?m=66827#review709123251',
#     'text': 'วัดนี้อยู่หลังกลาโหมสามารถเดินมาได้แต่ที่นี้ไม่มีที่จอดรถต้องจอดข้างทางตอนนี้ด้านในวัดกำลังบูรณะใหญ่อยู่หลายจุด',
#     'title': 'ไหว้สักการะ',
#     'trip_type': 'คู่รัก',
#     'travel_date': '2019-09-30',
#     'user': {'username': 'BestHealthiness',
#      'user_location': {'id': '293916', 'name': 'Bangkok'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/15/ad/6c/5c/besthealthiness.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/15/ad/6c/5c/besthealthiness.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/15/ad/6c/5c/besthealthiness.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-o/15/ad/6c/5c/besthealthiness.jpg'}},
#     'subratings': {}},
#    {'id': 342730116,
#     'lang': 'th',
#     'location_id': 2273363,
#     'published_date': '2016-01-26T00:39:37Z',
#     'rating': 5,
#     'helpful_votes': 1,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d2273363-r342730116-Reviews-Wat_Rajapradit_Sathitmahasimaram_Rajaworavihara-Bangkok.html?m=66827#review342730116',
#     'text': 'วัดแห่งนี้เป็นวัดประจำรัชกาลที่ 4 จึงเป็นวัดนิกายธรรมยุต มีขนาดเล็ก มีสีมาชิดติดกับพระอุโบสถจึงมีสร้อยนามของวัดว่า สถิตมหาสีมาราม สามารถเดินเที่ยวชมได้ใช้เวลาไม่นาน',
#     'title': 'วัดหลวง ประจำรัชกาล',
#     'trip_type': 'เดินทางคนเดียว',
#     'travel_date': '2016-01-31',
#     'user': {'username': 'kit20m',
#      'user_location': {'id': 'null'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/07/71/75/49/kit20m.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/07/71/75/49/kit20m.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/07/71/75/49/kit20m.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-s/07/71/75/49/kit20m.jpg'}},
#     'subratings': {}},
#    {'id': 336402386,
#     'lang': 'th',
#     'location_id': 2273363,
#     'published_date': '2016-01-01T10:43:00Z',
#     'rating': 4,
#     'helpful_votes': 1,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s4.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d2273363-r336402386-Reviews-Wat_Rajapradit_Sathitmahasimaram_Rajaworavihara-Bangkok.html?m=66827#review336402386',
#     'text': 'อยู่ใกล้กับสวนสราณรมย์ เป็นพระอารามหลวงชั้นเอก ที่รัชกาลที่ 4 โปรดเกล้าฯให้สร้างขึ้น โดยมีปราสาทพระรูปของพระองค์ท่านอยู่ภายในพื้นที่ ตอนนี้อยู่ในช่วงการบูรณะพื้นที่',
#     'title': 'วัดประจำรัชกาลที่ 4',
#     'trip_type': 'NONE',
#     'travel_date': '2015-12-31',
#     'user': {'username': 'doypui',
#      'user_location': {'id': 'null'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/07/9b/83/10/doypui.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/07/9b/83/10/doypui.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/07/9b/83/10/doypui.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/07/9b/83/10/doypui.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/07/9b/83/10/doypui.jpg'}},
#     'subratings': {}},
#    {'id': 336150114,
#     'lang': 'th',
#     'location_id': 2273363,
#     'published_date': '2015-12-31T04:48:53Z',
#     'rating': 5,
#     'helpful_votes': 1,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d2273363-r336150114-Reviews-Wat_Rajapradit_Sathitmahasimaram_Rajaworavihara-Bangkok.html?m=66827#review336150114',
#     'text': 'เป็นอารามหลวงขนาดเล็ก ประตูบานไม้แกะสลักสวยมาก เหทาะกับคนชอบศิลปะแนวแกะสลักๆ เหมาะกับคนมีเวลาไม่มาก เดินทางมาไม่ยากอยู่ติดกับพระราชอุทยานสราญรมย์ ',
#     'title': 'อารามหลวงขนาดเล็ก เหมาะกับคนมีเวลาไม่มาก',
#     'trip_type': 'NONE',
#     'travel_date': '2015-10-31',
#     'user': {'username': 'graciosob',
#      'user_location': {'id': 'null'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/08/18/83/24/graciosob.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/08/18/83/24/graciosob.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/08/18/83/24/graciosob.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-s/08/18/83/24/graciosob.jpg'}},
#     'subratings': {}}]},
#  {'311043': [{'id': 955580802,
#     'lang': 'th',
#     'location_id': 311043,
#     'published_date': '2024-06-17T22:39:12Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d311043-r955580802-Reviews-Wat_Phra_Chetuphon-Bangkok.html?m=66827#review955580802',
#     'text': 'สวยงาม และเป็นแหล่งดึงถูดนักท่องเที่ยวทั่วโลกและยังมีบริการนวดวัดโพธิ์ให้บริการในวัด บรรยากาศร่มเย็น จิตใจสงบ',
#     'title': 'นวดวัดโพธิ์',
#     'trip_type': 'เดินทางกับเพื่อน',
#     'travel_date': '2024-03-31',
#     'user': {'username': 'Inspire02466305332',
#      'user_location': {'id': '293917', 'name': 'Chiang Mai'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/2c/98/25/09/inspire02466305332.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/2c/98/25/09/inspire02466305332.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/2c/98/25/09/inspire02466305332.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/2c/98/25/09/inspire02466305332.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-m/1280/2c/98/25/09/inspire02466305332.jpg'}},
#     'subratings': {}},
#    {'id': 947729893,
#     'lang': 'th',
#     'location_id': 311043,
#     'published_date': '2024-04-21T13:57:16Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d311043-r947729893-Reviews-Wat_Phra_Chetuphon-Bangkok.html?m=66827#review947729893',
#     'text': 'วัดที่สวยงาม น่าสักการะกราบไหว้ สถานที่ดี เดินทางสะดวก พาครอบครัวมาเที่ยว ทุกคนชอบประทับใจ จิตใจสงบ ได้ทำบุญ ทำสมาธิ แนะนำทุกคนเพื่อความสงบ',
#     'title': 'วัดโพธิ์',
#     'trip_type': 'ครอบครัว',
#     'travel_date': '2023-05-31',
#     'user': {'username': 'says682',
#      'user_location': {'id': '293916', 'name': 'Bangkok'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/f6/ee/68/default-avatar-2020-9.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/f6/ee/68/default-avatar-2020-9.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/f6/ee/68/default-avatar-2020-9.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/1a/f6/ee/68/default-avatar-2020-9.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/f6/ee/68/default-avatar-2020-9.jpg'}},
#     'subratings': {}},
#    {'id': 920942480,
#     'lang': 'th',
#     'location_id': 311043,
#     'published_date': '2023-10-12T08:38:35Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d311043-r920942480-Reviews-Wat_Phra_Chetuphon-Bangkok.html?m=66827#review920942480',
#     'text': 'UNESCO ได้ขึ้นทะเบียนให้มรดกความทรงจำแห่งโลก มีนักท่องเที่ยวเข้ามาภายในวัดค่อนข้างเยอะ เหมาะแก่การมาสักการะบูชา เพื่อเป็นสิริมงคล',
#     'title': 'วัดพระเชตุพนวิมลมังคลาราม (วัดโพธิ์ท่าเตียน)  ',
#     'trip_type': 'ครอบครัว',
#     'travel_date': '2023-08-31',
#     'user': {'username': 'Chuanmanon',
#      'user_location': {'id': '293916', 'name': 'Bangkok'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/2a/90/74/59/caption.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/2a/90/74/59/caption.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/2a/90/74/59/caption.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-s/2a/90/74/59/caption.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-m/1280/2a/90/74/59/caption.jpg'}},
#     'subratings': {}},
#    {'id': 893696251,
#     'lang': 'th',
#     'location_id': 311043,
#     'published_date': '2023-06-06T08:20:08Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d311043-r893696251-Reviews-Wat_Phra_Chetuphon-Bangkok.html?m=66827#review893696251',
#     'text': 'วัดสวยงาม เเต่ชาวต่างชาติค่อนข้างเยอะ คนเเน่นวัด อยากถ่ายรูปสวยๆก็หาจังหวะยากมาก ภายในวัดสะอาดสะอ้าน การจัดการดี',
#     'title': 'วัดพระน้อนนน',
#     'trip_type': 'NONE',
#     'travel_date': '2023-06-30',
#     'user': {'username': 'boonmap4456',
#      'user_location': {'id': '293916', 'name': 'Bangkok'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/08/46/a2/11/jaonaiaspen.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/08/46/a2/11/jaonaiaspen.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/08/46/a2/11/jaonaiaspen.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/08/46/a2/11/jaonaiaspen.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/08/46/a2/11/jaonaiaspen.jpg'}},
#     'subratings': {}},
#    {'id': 888779420,
#     'lang': 'th',
#     'location_id': 311043,
#     'published_date': '2023-05-03T04:20:20Z',
#     'rating': 4,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s4.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d311043-r888779420-Reviews-Wat_Phra_Chetuphon-Bangkok.html?m=66827#review888779420',
#     'text': 'คนพลุกพล่านมากถ่ายรูปยากสถานที่ๆคนส่วนใหญ่มายืนออทางเข้าอยากจะมาอีกครั้งให้ได้รูปมากกว่านี้ คราวหลังจะเลือกวันมา แต่ก็ประทับใจครับ',
#     'title': 'ดีครับ',
#     'trip_type': 'เดินทางคนเดียว',
#     'travel_date': '2023-05-31',
#     'user': {'username': 'suphakits2023',
#      'user_location': {'id': 'null'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/f6/e9/60/default-avatar-2020-64.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/f6/e9/60/default-avatar-2020-64.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/f6/e9/60/default-avatar-2020-64.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/1a/f6/e9/60/default-avatar-2020-64.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/f6/e9/60/default-avatar-2020-64.jpg'}},
#     'subratings': {}}]},
#  {'317504': [{'id': 951578481,
#     'lang': 'th',
#     'location_id': 317504,
#     'published_date': '2024-05-20T04:58:50Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d317504-r951578481-Reviews-Temple_Of_Dawn_Wat_Arun-Bangkok.html?m=66827#review951578481',
#     'text': 'ไปวัดอรุณฯ รู้สึกเหมือนตัวเองเป็นคนแปลกถิ่นมาเที่ยว เพราะวัดนี้เป็นสถานที่ท่องเที่ยวยอดนิยมของนักท่องเที่ยวจีนไปแล้ว ถือว่าประสบความสำเร็จอย่างสูงในด้านดึงดูดนักท่องเที่ยว บนพระปรางคนเบียดเสียดจนไม่น่าเชื่อ แถมรถติดยาวหน้าวัด\n\nคนไทยเข้าฟรี ต่างชาติต้องจ่ายค่าเข้า\n\nจุดเด่นคือ คนมาเช่าชุดไทย เพื่อใส่ถ่ายรูป วันที่มาเห็นคนจีนแต่งชุดไทยมากที่สุด คนไทยมีประปราย เห็นฝรั่งหนึ่งกลุ่มกับสาวแขกสองคนที่เช่าชุดไทยแต่งกับเขาด้วย ที่นี่มีบริการจ้างตากล้องด้วย สะดวกดีค่ะ กิจการร้านเช่าชุดไทยจึงดูคึกคักวุ่นวายหน้าวัดเป็นอย่างยิ่ง ในช่วงบ่ายแก่ ๆ จนถึงเย็น เพื่อเลี่ยงแดดร้อน\n\nไอติมลายกระเบื้องวัดอรุณแพงมาก แท่งละ 89 บาท เลยไม่ได้ชิม\n\nถึงอย่างไรก็ตาม พระปรางวัดอรุณฯ ก็ยังคงความสวยงาม อลังการ อยู่เหมือนเดิม\n\nถ้ามาวัดนี้ อย่าลืมมาลอดพระแท่นพระเจ้าตาก  กราบขอพรพระบารมี ลอดใต้ฐาน มีความเชื่อ ล้างอาถรรพ์ แก้ไขดวงชะตาไม่ดี',
#     'title': 'Beautiful temple at sunset',
#     'trip_type': 'เดินทางกับเพื่อน',
#     'travel_date': '2024-05-31',
#     'user': {'username': 'Go07871511649',
#      'user_location': {'id': 'null'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/f6/e2/e6/default-avatar-2020-45.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/f6/e2/e6/default-avatar-2020-45.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/f6/e2/e6/default-avatar-2020-45.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/1a/f6/e2/e6/default-avatar-2020-45.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/f6/e2/e6/default-avatar-2020-45.jpg'}},
#     'subratings': {}},
#    {'id': 949994236,
#     'lang': 'th',
#     'location_id': 317504,
#     'published_date': '2024-05-08T06:12:13Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d317504-r949994236-Reviews-Temple_Of_Dawn_Wat_Arun-Bangkok.html?m=66827#review949994236',
#     'text': 'วิวสวย วัดสวยมากครับ แต่คนเยอะเช่นกันครับ ถ้าเอาลูกไปด้วยแนะนำพกพักลมพกพาไปด้วยจะดีมากครับ ไม่แนะนำเอารถส่วนตัวมา หาที่จอดรถยาก',
#     'title': 'วิวสวย',
#     'trip_type': 'ครอบครัว',
#     'travel_date': '2024-04-30',
#     'user': {'username': 'Sherpa45681108283',
#      'user_location': {'id': 'null'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/f6/e3/1f/default-avatar-2020-46.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/f6/e3/1f/default-avatar-2020-46.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/f6/e3/1f/default-avatar-2020-46.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/1a/f6/e3/1f/default-avatar-2020-46.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/f6/e3/1f/default-avatar-2020-46.jpg'}},
#     'subratings': {}},
#    {'id': 949610088,
#     'lang': 'th',
#     'location_id': 317504,
#     'published_date': '2024-05-05T12:20:05Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d317504-r949610088-Reviews-Temple_Of_Dawn_Wat_Arun-Bangkok.html?m=66827#review949610088',
#     'text': 'วัดอรุณราชวรารามราชวรมหาวิหาร เป็นวัดที่งดงามวัดตั้งอยู่ริมแม่น้ำเจ้าพระยาในกรุงเทพมหานคร เป็นสถานที่ท่องเที่ยวเชิงวัฒนธรรมของชาวต่างชาติ วัดแห่งนี้ถือได้ว่าเป็นแลนด์มาร์กของนักท่องเที่ยวทั่วทุกมุมโลก จะมาใส่ชุดไทยไปเดินเล่นถ่ายรูปสวยๆ ในบริเวณวัด  จุดไฮไลท์ของ ของวัดอรุณฯ ได้แก่ พระปรางค์ใหญ่, พระอุโบสถ สักการะพระพุทธธรรมมิศรราชโลกธาตุดิลก, พระวิหารหลวง, โบสถ์น้อย ลอดแท่นบรรทมสมเด็จพระเจ้าตากสินมหาราช และยักษ์บริเวณซุ้มประตูทางเข้า หรือที่หลายๆ คนเรียกว่ายักษ์วัดแจ้ง วัดอรุณฯ เหมาะกับการทำบุญเสริมสิริมงคลในวันปีใหม่และเริ่มต้นสิ่งใหม่ๆ ถือเอาชื่อวัดเป็นสำคัญ ทุกชีวิตมักเริ่มต้นใหม่ในรุ่งเช้า',
#     'title': 'Temple of culture',
#     'trip_type': 'เดินทางกับเพื่อน',
#     'travel_date': '2024-05-31',
#     'user': {'username': 'sutidak2024',
#      'user_location': {'id': 'null'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/f6/ea/b2/default-avatar-2020-69.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/f6/ea/b2/default-avatar-2020-69.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/f6/ea/b2/default-avatar-2020-69.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/1a/f6/ea/b2/default-avatar-2020-69.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/f6/ea/b2/default-avatar-2020-69.jpg'}},
#     'subratings': {}},
#    {'id': 948942290,
#     'lang': 'th',
#     'location_id': 317504,
#     'published_date': '2024-04-30T11:32:56Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d317504-r948942290-Reviews-Temple_Of_Dawn_Wat_Arun-Bangkok.html?m=66827#review948942290',
#     'text': 'เมื่อวันก่อน อยากไปถ่ายภาพวัดอรุณ เพราะอยากได้รูปนำไปลงในเวบ WEIBO ของจีน\nจึงไปที่ท่าเรือวัดโพธิ์ อยู่ฝั่งตรงข้าม เยื้องๆนิดหน่อย วัดอรุณเป็นแลนด์มาร์คของประเทศไทย เป็นที่สนใจของชาวต่างชาติเป็นอย่างยิ่ง ที่ท่าเรือชาวต่างชาติ ทั้ง ชาวจีน ฝรั่ง เกาหลี ญี่ปุ่นแน่นมาก แทบไม่มีที่จุดยืนถ่ายภาพ\nแต่ในวันนี้ท้องฟ้าค่อนข้างปิด จึงได้ท้องฟ้ายามเย็นไม่ค่อยสวย แต่ช่วงทไวไลท์ก็พอใช้ได้\n',
#     'title': 'Suayyy',
#     'trip_type': 'เดินทางคนเดียว',
#     'travel_date': '2024-04-30',
#     'user': {'username': 'Dreamer45490085972',
#      'user_location': {'id': '293916', 'name': 'Bangkok'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/f6/f0/48/default-avatar-2020-15.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/f6/f0/48/default-avatar-2020-15.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/f6/f0/48/default-avatar-2020-15.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/1a/f6/f0/48/default-avatar-2020-15.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/f6/f0/48/default-avatar-2020-15.jpg'}},
#     'subratings': {}},
#    {'id': 944528892,
#     'lang': 'th',
#     'location_id': 317504,
#     'published_date': '2024-03-30T12:35:38Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d317504-r944528892-Reviews-Temple_Of_Dawn_Wat_Arun-Bangkok.html?m=66827#review944528892',
#     'text': 'เป็นสถานที่ท่องเที่ยวที่มีความโดดเด่นไม่เหมือนที่ไหนมีความเป็นเอกลักษณ์ ที่แสดงความเป็นไทยอย่างโดดเด่นและเหมาะที่จะให้ชาวต่างชาติมาเยี่ยมชม เป็นจุดเด่นสำคัญที่ใครมาประเทศไทยก็ต้องมาที่แห่งนี้😍😍🤭',
#     'title': 'เป็นวัดเก่าเเก่ที่สวยงามมีประวัติศาสตร์ที่น่าหลงไหล มีความเป็นไทย และสถาปัตยกรรมโดนเด่น เป็นแหล่งท่องเที่ยวคู่บ้าน คู่เมืองเหมาะ',
#     'trip_type': 'เดินทางกับเพื่อน',
#     'travel_date': '2024-03-31',
#     'user': {'username': 'Journey45923260840',
#      'user_location': {'id': '293916', 'name': 'Bangkok'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/f6/ef/32/default-avatar-2020-12.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/f6/ef/32/default-avatar-2020-12.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/f6/ef/32/default-avatar-2020-12.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/1a/f6/ef/32/default-avatar-2020-12.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/f6/ef/32/default-avatar-2020-12.jpg'}},
#     'subratings': {}}]},
#  {'456322': [{'id': 895463047,
#     'lang': 'th',
#     'location_id': 456322,
#     'published_date': '2023-06-16T15:33:52Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293917-d456322-r895463047-Reviews-Wat_Umong-Chiang_Mai.html?m=66827#review895463047',
#     'text': 'เป็นวัดเก่าแก่ของเชียงใหม่ บรรยากาศร่มรื่นสีเขียว อากาศบริสุทธิ์ มุมถ่ายรูปสวย มุมแปลกๆเยอะมาก รู้สึกสงบจิตสงบใจ ได้รับพลังงานดีๆ เรียกได้ว่าเป็นมุมสงบของเชียงใหม่เลยก็ว่าได้',
#     'title': 'วัดทรงคุณค่าทางวัฒนธรรม',
#     'trip_type': 'เดินทางกับเพื่อน',
#     'travel_date': '2023-04-30',
#     'user': {'username': 'Jet67176457521',
#      'user_location': {'id': '293916', 'name': 'Bangkok'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/f6/f2/b8/default-avatar-2020-26.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/f6/f2/b8/default-avatar-2020-26.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/f6/f2/b8/default-avatar-2020-26.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/1a/f6/f2/b8/default-avatar-2020-26.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/f6/f2/b8/default-avatar-2020-26.jpg'}},
#     'subratings': {}},
#    {'id': 780996969,
#     'lang': 'th',
#     'location_id': 456322,
#     'published_date': '2021-01-11T21:54:27Z',
#     'rating': 5,
#     'helpful_votes': 11,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293917-d456322-r780996969-Reviews-Wat_Umong-Chiang_Mai.html?m=66827#review780996969',
#     'text': 'ช่วงที่ไปเป็นฤดูฝนทำให้อากาศดีมากๆ ฟ้าครื้มแต่อากาศสดชื่น ต้นไม้สีเขียว สบายตามากๆค่ะ ภายในอุโมงค์สงบมาก เดินขึ้นมาเรื่อยๆจะเจอตามรูปแรก สวยมากและสงบมาก ต้นไม้เยอะดีค่ะ',
#     'title': 'สงบ สดชื่น สบายใจ',
#     'trip_type': 'คู่รัก',
#     'travel_date': '2020-07-31',
#     'user': {'username': 'THEN92',
#      'user_location': {'id': '293916', 'name': 'Bangkok'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1c/84/2c/49/caption.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1c/84/2c/49/caption.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1c/84/2c/49/caption.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-s/1c/84/2c/49/caption.jpg'}},
#     'subratings': {}},
#    {'id': 775633244,
#     'lang': 'th',
#     'location_id': 456322,
#     'published_date': '2020-10-26T08:03:37Z',
#     'rating': 5,
#     'helpful_votes': 1,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293917-d456322-r775633244-Reviews-Wat_Umong-Chiang_Mai.html?m=66827#review775633244',
#     'text': 'ไปเชียงใหม่หลายครัั้งแต่ไม่เคยไปวัดแห่งนี้เลย เมื่อได้เข้าไปภายในวัด ร่มรื่น ไปด้วยต้นไม้ เนื่องจากอยู่ใกล้ภูเขา เชิงดอยสุเทพ มีอุโมงค์เดินเข้าไปสวยงามมาก มีความเก่าแก่ ดูขลัง สามารถเข้าไปกราบพระพุทธรูปภายในอุโมงได้  อุโมงค์จะมี 3 ทางเข้าสามารถทะลุถึงกันได้ สวยงามมาก ต้อไปให้ได้ครับ',
#     'title': 'วัดตามชื่อคือ อุโมงค์',
#     'trip_type': 'NONE',
#     'travel_date': '2020-09-30',
#     'user': {'username': 'samran900',
#      'user_location': {'id': '297921', 'name': 'Hat Yai, Songkhla Province'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/14/cb/2a/e5/samran900.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/14/cb/2a/e5/samran900.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/14/cb/2a/e5/samran900.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-s/14/cb/2a/e5/samran900.jpg'}},
#     'subratings': {}},
#    {'id': 745355824,
#     'lang': 'th',
#     'location_id': 456322,
#     'published_date': '2020-02-16T02:12:55Z',
#     'rating': 5,
#     'helpful_votes': 1,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293917-d456322-r745355824-Reviews-Wat_Umong-Chiang_Mai.html?m=66827#review745355824',
#     'text': 'ที่จอดรถยนต์ค่อนข้างน้อย  \nภายในวัดมีความร่มรื่น\nมีจุดให้บริการซื้ออาหารปลา\nวัดและเจดย์มีมนต์ขลัง มีเสน่ห์แบบไม่เหมือนใคร   มีความเงียบสงบมาก  เหมาะแก่การไปนั่งสมาธิ',
#     'title': 'วัดที่ไม่เหมือนใคร และมีเอกลักษณ์ประจำตัว มีมนต์ขลัง',
#     'trip_type': 'NONE',
#     'travel_date': '2020-02-29',
#     'user': {'username': '946thaih',
#      'user_location': {'id': '293917', 'name': 'Chiang Mai'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/0c/5c/d0/f5/thai-h.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/0c/5c/d0/f5/thai-h.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/0c/5c/d0/f5/thai-h.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-s/0c/5c/d0/f5/thai-h.jpg'}},
#     'subratings': {}},
#    {'id': 736153803,
#     'lang': 'th',
#     'location_id': 456322,
#     'published_date': '2020-01-01T22:22:09Z',
#     'rating': 5,
#     'helpful_votes': 1,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293917-d456322-r736153803-Reviews-Wat_Umong-Chiang_Mai.html?m=66827#review736153803',
#     'text': 'เป็นวัดที่สงบ ร่มรื่น เหมาะแก่การมาเยี่ยมชมและมาปฏิบัติธรรม สามารถมาเที่ยวชมได้ในรูปแบบกลุ่ม หรือท่องเที่ยวตามลำพัง วัดอยู่นอกเมืองเชียงใหม่พอสมควร',
#     'title': 'สงบ ร่มรื่น',
#     'trip_type': 'NONE',
#     'travel_date': '2019-12-31',
#     'user': {'username': 'NPjourney',
#      'user_location': {'id': 'null'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/f6/de/5a/default-avatar-2020-36.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/f6/de/5a/default-avatar-2020-36.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/f6/de/5a/default-avatar-2020-36.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/1a/f6/de/5a/default-avatar-2020-36.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/f6/de/5a/default-avatar-2020-36.jpg'}},
#     'subratings': {}}]},
#  {'1368436': [{'id': 956594374,
#     'lang': 'th',
#     'location_id': 1368436,
#     'published_date': '2024-06-24T22:58:58Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g297920-d1368436-r956594374-Reviews-Wat_Rong_Khun-Chiang_Rai_Chiang_Rai_Province.html?m=66827#review956594374',
#     'text': 'เป็นวัดที่สวยงานของจังหวัดเชียงราย นักท่องเที่ยวทั้งไทยและต่างชาติชอบมาเที่ยวชมความงามของวัดและงานศิลปะของอาจารย์เฉลิมชัยที่มีชื่อเสียงระดับโลก',
#     'title': 'มาเที่ยวเชียงรายไม่ควรพลาดมาเที่ยวชม',
#     'trip_type': 'เดินทางกับเพื่อน',
#     'travel_date': '2024-06-30',
#     'user': {'username': 'Odyssey44962354748',
#      'user_location': {'id': 'null'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/f6/e3/6a/default-avatar-2020-47.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/f6/e3/6a/default-avatar-2020-47.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/f6/e3/6a/default-avatar-2020-47.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/1a/f6/e3/6a/default-avatar-2020-47.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/f6/e3/6a/default-avatar-2020-47.jpg'}},
#     'subratings': {}},
#    {'id': 939897543,
#     'lang': 'th',
#     'location_id': 1368436,
#     'published_date': '2024-02-26T15:02:42Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g297920-d1368436-r939897543-Reviews-Wat_Rong_Khun-Chiang_Rai_Chiang_Rai_Province.html?m=66827#review939897543',
#     'text': 'มาหลายครั้ง แต่เป็นครั้งแรกที่เข้าชมถ้ำศิลป์ค่ะ เดินเข้าไปด้านในซื้อบัตรเข้าชมค่ะ  มีรูปหัวกระโหลก โควิดด้วยค่ะ  ตอนออกก็แวะซื้อโปสการ์ดเป็นที่ระลึกค่ะ',
#     'title': 'เข้าชมถ้ำศิลป์',
#     'trip_type': 'เดินทางกับเพื่อน',
#     'travel_date': '2023-08-31',
#     'user': {'username': 'jitsiri',
#      'user_location': {'id': '293916', 'name': 'Bangkok'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/19/76/c4/54/jitsiri.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/19/76/c4/54/jitsiri.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/19/76/c4/54/jitsiri.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/19/76/c4/54/jitsiri.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-m/1280/19/76/c4/54/jitsiri.jpg'}},
#     'subratings': {}},
#    {'id': 885886663,
#     'lang': 'th',
#     'location_id': 1368436,
#     'published_date': '2023-04-12T04:49:17Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g297920-d1368436-r885886663-Reviews-Wat_Rong_Khun-Chiang_Rai_Chiang_Rai_Province.html?m=66827#review885886663',
#     'text': 'ประทับใจมากในการไปเที่ยวครั้งนึงในจังหวัดเชียงราย มีโอกาสจะกลับไปอีกและแนะนำสหรับทุกท่านที่ยังไม่เคยไปค่ะ',
#     'title': 'ความสวยงามของวัดร่องขุ่น',
#     'trip_type': 'เดินทางคนเดียว',
#     'travel_date': '2023-04-30',
#     'user': {'username': 'Global09652969422',
#      'user_location': {'id': '186216', 'name': 'United Kingdom'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/f6/f1/b8/default-avatar-2020-22.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/f6/f1/b8/default-avatar-2020-22.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/f6/f1/b8/default-avatar-2020-22.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/1a/f6/f1/b8/default-avatar-2020-22.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/f6/f1/b8/default-avatar-2020-22.jpg'}},
#     'subratings': {}},
#    {'id': 835149074,
#     'lang': 'th',
#     'location_id': 1368436,
#     'published_date': '2022-04-19T06:55:12Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g297920-d1368436-r835149074-Reviews-Wat_Rong_Khun-Chiang_Rai_Chiang_Rai_Province.html?m=66827#review835149074',
#     'text': 'วัดร่องขุ่นอีกหนึ่งสถานที่ท่องเที่ยวที่มีชื่อเสียงของจังหวัดเชียงราย ก่อสร้างและออกแบบโดยอาจารย์เฉลิมชัย โฆษิตพิพัฒน์ ด้วยลวดลายศิลปะปูนปั้นที่มีสีขาว แสดงเรื่องราวเกี่ยวกับวัฏจักรของมนุษย์แฝงด้วยหลักธรรมทางพุทธศาสนา',
#     'title': 'วัดร่องขุ่นหรือ White temple',
#     'trip_type': 'ครอบครัว',
#     'travel_date': '2022-04-30',
#     'user': {'username': 'vanapong',
#      'user_location': {'id': '14053408',
#       'name': 'Ko Kret, Nonthaburi Province'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1b/a6/b0/23/vanapong.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1b/a6/b0/23/vanapong.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1b/a6/b0/23/vanapong.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/1b/a6/b0/23/vanapong.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-m/1280/1b/a6/b0/23/vanapong.jpg'}},
#     'subratings': {}},
#    {'id': 778173587,
#     'lang': 'th',
#     'location_id': 1368436,
#     'published_date': '2020-11-30T01:30:23Z',
#     'rating': 5,
#     'helpful_votes': 1,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g297920-d1368436-r778173587-Reviews-Wat_Rong_Khun-Chiang_Rai_Chiang_Rai_Province.html?m=66827#review778173587',
#     'text': 'วัดอยู่ห่างจากย่านตัวเมืองลงมาทางใต้หน่อย ไปวันธรรมดาคนไม่เยอะมาก มีที่จอดรถสบายๆ คนไทยเข้าชมฟรี ชอบศิลปะการตกแต่งของที่นี่สวยงามมาก',
#     'title': 'สวยงามมาก',
#     'trip_type': 'ครอบครัว',
#     'travel_date': '2020-11-30',
#     'user': {'username': 'SweetyLollipop',
#      'user_location': {'id': '293916', 'name': 'Bangkok'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/12/b7/08/32/sweetylollipop.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/12/b7/08/32/sweetylollipop.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-o/12/b7/08/32/sweetylollipop.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-s/12/b7/08/32/sweetylollipop.jpg'}},
#     'subratings': {}}]},
#  {'7913913': [{'id': 920975978,
#     'lang': 'th',
#     'location_id': 7913913,
#     'published_date': '2023-10-12T12:51:01Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d7913913-r920975978-Reviews-Wat_Pak_Nam-Bangkok.html?m=66827#review920975978',
#     'text': 'วัดปากน้ำภาษีเจริญ เป็นวัดที่มีชื่อเสียง มีความเก่าแก่ตั้งแต่สมัยกรุงศรีอยุธยา วัดอยู่ติดกับริมคลองบางกอกใหญ่\nมีพระพุทธรูปปางสมาธิ เกศดอกบัวตูม สูง 69 เมตร',
#     'title': 'วัดปากน้ำ',
#     'trip_type': 'คู่รัก',
#     'travel_date': '2022-11-30',
#     'user': {'username': 'Chuanmanon',
#      'user_location': {'id': '293916', 'name': 'Bangkok'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/2a/90/74/59/caption.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/2a/90/74/59/caption.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/2a/90/74/59/caption.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-s/2a/90/74/59/caption.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-m/1280/2a/90/74/59/caption.jpg'}},
#     'subratings': {}},
#    {'id': 902420478,
#     'lang': 'th',
#     'location_id': 7913913,
#     'published_date': '2023-07-12T07:40:24Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d7913913-r902420478-Reviews-Wat_Pak_Nam-Bangkok.html?m=66827#review902420478',
#     'text': 'เป็นวัดที่สวยมาก และเข้าฟรี คนเยอะมากทั้งคนไทยและชาวต่างชาติ ห้องน้ำเยอะ ถือว่าสะอาด เดินทางสะดวกด้วยรถไฟฟ้า สามารถเดินไปวัดในระยะไม่เกิน15นาที ใกล้ๆสถานีก็มีอาหารข้างทางอร่อยๆหลายเจ้าด้วยค่ะ',
#     'title': 'เป็นอีกวัดที่สวยมาก เข้าฟรี และเดินทางสะดวกมากๆค่ะ',
#     'trip_type': 'เดินทางกับเพื่อน',
#     'travel_date': '2023-07-31',
#     'user': {'username': 'Lonelycat64',
#      'user_location': {'id': 'null'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/f6/f3/23/default-avatar-2020-28.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/f6/f3/23/default-avatar-2020-28.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/f6/f3/23/default-avatar-2020-28.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/1a/f6/f3/23/default-avatar-2020-28.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/f6/f3/23/default-avatar-2020-28.jpg'}},
#     'subratings': {}},
#    {'id': 867790849,
#     'lang': 'th',
#     'location_id': 7913913,
#     'published_date': '2022-11-09T06:23:06Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d7913913-r867790849-Reviews-Wat_Pak_Nam-Bangkok.html?m=66827#review867790849',
#     'text': 'วัดสวยมาก มีพระใหญ่ๆๆๆๆๆๆ เดินจากบีทีเอสตลาดพลูได้อยู่  ได้อยู่เท่ากับสองกิโล แต่ว่าเพลินๆก็ร้อนดี วัดใหญ่มากกกกก เดินขาลาก ไม่น่าจะได้บุญ',
#     'title': 'วัดสวย',
#     'trip_type': 'เดินทางกับเพื่อน',
#     'travel_date': '2022-10-31',
#     'user': {'username': 'Thiwapol55',
#      'user_location': {'id': 'null'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/f6/ec/3d/default-avatar-2020-1.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/f6/ec/3d/default-avatar-2020-1.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/f6/ec/3d/default-avatar-2020-1.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/1a/f6/ec/3d/default-avatar-2020-1.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/f6/ec/3d/default-avatar-2020-1.jpg'}},
#     'subratings': {}},
#    {'id': 864357861,
#     'lang': 'th',
#     'location_id': 7913913,
#     'published_date': '2022-10-13T09:12:51Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d7913913-r864357861-Reviews-Wat_Pak_Nam-Bangkok.html?m=66827#review864357861',
#     'text': 'ไปเที่ยวกับเพื่อนๆ ประมาน 10 คน พากันไปวันหยุดชอบมากเลย บรรยากาศดี วัดร่มรื่นมาก มีอาหารนิดๆหน่อยขายข้างทาง ป้าๆใจเีมากกไว้จะไปอีก',
#     'title': 'Stunning',
#     'trip_type': 'เดินทางคนเดียว',
#     'travel_date': '2022-10-31',
#     'user': {'username': 'Travel51219104945',
#      'user_location': {'id': '293916', 'name': 'Bangkok'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/f6/e8/24/default-avatar-2020-60.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/f6/e8/24/default-avatar-2020-60.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/f6/e8/24/default-avatar-2020-60.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/1a/f6/e8/24/default-avatar-2020-60.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/f6/e8/24/default-avatar-2020-60.jpg'}},
#     'subratings': {}},
#    {'id': 862852844,
#     'lang': 'th',
#     'location_id': 7913913,
#     'published_date': '2022-10-02T06:50:08Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293916-d7913913-r862852844-Reviews-Wat_Pak_Nam-Bangkok.html?m=66827#review862852844',
#     'text': 'สถานที่นี้ ศักดิ์สิทธิ์จริงค่ะ ชอบชวน เพื่อนเพื่อนมาสักการะเวลาหยุดตรงกัน มีจุดถ่ายรูปอยู่เบอร์สวยด้วยเดินทางมาก็ไม่ยากอยากแนะนำอยากบอกต่อ ทำบุญแล้วสบายใจดีค่ะโชคดีเฮงเฮงปังปัง',
#     'title': 'เชิญชวนมาไหว้พระ',
#     'trip_type': 'คู่รัก',
#     'travel_date': '2022-10-31',
#     'user': {'username': 'Curious33768922979',
#      'user_location': {'id': '293916', 'name': 'Bangkok'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/f6/e4/59/default-avatar-2020-49.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/f6/e4/59/default-avatar-2020-49.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/f6/e4/59/default-avatar-2020-49.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/1a/f6/e4/59/default-avatar-2020-49.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/f6/e4/59/default-avatar-2020-49.jpg'}},
#     'subratings': {}}]},
#  {'447648': [{'id': 935462665,
#     'lang': 'th',
#     'location_id': 447648,
#     'published_date': '2024-01-24T21:31:39Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g293917-d447648-r935462665-Reviews-Wat_Phra_Singh-Chiang_Mai.html?m=66827#review935462665',
#     'text': 'ทุกครั้งที่มา #วัดพระสิงห์วรมหาวิหาร จะชอบใช้เวลาที่อาคารหลังเล็กด้านใน เน้น #ภาพจิตรกรรมฝาผนัง เป็นพิเศษครับ',
#     'title': 'จิตรกรรมฝาผนังสวยงาม',
#     'trip_type': 'เดินทางคนเดียว',
#     'travel_date': '2023-11-30',
#     'user': {'username': 'MrTravelonCyber',
#      'user_location': {'id': '293916', 'name': 'Bangkok'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/29/f8/83/7b/mrtraveloncyber.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/29/f8/83/7b/mrtraveloncyber.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/29/f8/83/7b/mrtraveloncyber.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/29/f8/83/7b/mrtraveloncyber.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-w/29/f8/83/7b/mrtraveloncyber.jpg'}},
#     'subratings': {}},
#    {'id': 885262041,
#     'lang': 'th',
#     'location_id': 447648,
#     'published_date': '2023-04-08T01:43:19Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
# ...
#     'rating': 3,
#     'helpful_votes': 2,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s3.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g303913-d15274797-r730209315-Reviews-Pha_Hi_Village-Mae_Sai_Chiang_Rai_Province.html?m=66827#review730209315',
#     'text': 'เป็นหมู่บ้านอาข่าก็เป็นชาวเขาทั่วไปที่มีวิถีชีวิตที่พัฒนามาตอบรับนักท่องเที่ยว อากาศโดยทั่วไปดีแต่ช่วงที่ไปแดดแรงมาก ได้ไปทานกาแฟได้ไปเดินสะพานไม้ไผ่ก็เป็นประสบการณ์ที่ดีครับ',
#     'title': 'ไม่เคยไปก็ต้องไปดูให้เห็น',
#     'trip_type': 'เดินทางกับเพื่อน',
#     'travel_date': '2019-11-30',
#     'user': {'username': 'thitisaks2019',
#      'user_location': {'id': 'null'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/f6/e7/99/default-avatar-2020-57.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/f6/e7/99/default-avatar-2020-57.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/f6/e7/99/default-avatar-2020-57.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/1a/f6/e7/99/default-avatar-2020-57.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/f6/e7/99/default-avatar-2020-57.jpg'}},
#     'subratings': {}},
#    {'id': 716870545,
#     'lang': 'th',
#     'location_id': 15274797,
#     'published_date': '2019-10-09T21:22:51Z',
#     'rating': 5,
#     'helpful_votes': 1,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g303913-d15274797-r716870545-Reviews-Pha_Hi_Village-Mae_Sai_Chiang_Rai_Province.html?m=66827#review716870545',
#     'text': 'สวยมาก เช้านี้หมอกไม่เยอะ แต่อากาศดีมากๆ ที่พักสวย สะอาด ปลอดภัย อาหารของที่พักอร่อย ราคาไม่แพง ต้องกลับมาอีกครั้งแน่นอน',
#     'title': 'เช้านี้ที่ดอยผาฮี๊',
#     'trip_type': 'ครอบครัว',
#     'travel_date': '2019-10-31',
#     'user': {'username': 'jackerf2017',
#      'user_location': {'id': '1800625', 'name': 'Nuea Khlong, Krabi Province'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/17/bb/c6/07/jackerf2017.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/17/bb/c6/07/jackerf2017.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/17/bb/c6/07/jackerf2017.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/17/bb/c6/07/jackerf2017.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-m/1280/17/bb/c6/07/jackerf2017.jpg'}},
#     'subratings': {}},
#    {'id': 706354501,
#     'lang': 'th',
#     'location_id': 15274797,
#     'published_date': '2019-09-04T05:48:31Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g303913-d15274797-r706354501-Reviews-Pha_Hi_Village-Mae_Sai_Chiang_Rai_Province.html?m=66827#review706354501',
#     'text': 'ได้มีโอกาสไปเที่ยวเชียงรายครั้งนี้ถือว่าคุ้มมาก เราขับรถตระเวณไปเรื่อยๆ บนถนนที่ลัดเลาะ คดเคี้ยว ขึ้นภูเขา ไปยังหมู่บ้านแห่งนี้ ในระหว่างทาง ทิวเขาสลับซับซ้อน อากาศดีมากๆ พอไปถึง ดอยผาฮี้ มันคือดีมาก วิวสวย อากาศดี ผู้คนน่ารัก หมู่บ้านนี้นอกจากอากาศดีแล้ว ยังมีร้านกาแฟหอมกรุ่น ที่โด่งดังไปทั่วโลก นั่งจิบกาแฟไป ชมวิวไป โอ๊ย มันฟินสุดขีด แทบอยากย้ายถิ่นฐานมาอยู่ที่นี่เลย ',
#     'title': 'ผาฮี้ เชียงราย',
#     'trip_type': 'NONE',
#     'travel_date': '2019-09-30',
#     'user': {'username': 'phuban',
#      'user_location': {'id': '2237167',
#       'name': 'Bang Bua Thong, Nonthaburi Province'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/15/21/f7/12/caption.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/15/21/f7/12/caption.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/15/21/f7/12/caption.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-s/15/21/f7/12/caption.jpg'}},
#     'subratings': {}},
#    {'id': 705950293,
#     'lang': 'th',
#     'location_id': 15274797,
#     'published_date': '2019-09-03T09:08:17Z',
#     'rating': 4,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s4.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g303913-d15274797-r705950293-Reviews-Pha_Hi_Village-Mae_Sai_Chiang_Rai_Province.html?m=66827#review705950293',
#     'text': 'ชุมชนเล็กๆบนดอยสูง อยู่ระหว่างทางลงจากดอยตุง ไปดอยผาหมี ถ้ำนางนอน แวะพักรถที่นี้กันก่อน มีร้านกาแฟ และร้านอาหารให้ชมและชมวิวที่สวยงาม',
#     'title': 'ชุมชนเล็กๆบนดอยสูง',
#     'trip_type': 'ครอบครัว',
#     'travel_date': '2019-02-28',
#     'user': {'username': 'doypui',
#      'user_location': {'id': 'null'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/07/9b/83/10/doypui.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/07/9b/83/10/doypui.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/07/9b/83/10/doypui.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/07/9b/83/10/doypui.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/07/9b/83/10/doypui.jpg'}},
#     'subratings': {}}]},
#  {'4322826': [{'id': 729731083,
#     'lang': 'th',
#     'location_id': 4322826,
#     'published_date': '2019-11-30T02:42:40Z',
#     'rating': 5,
#     'helpful_votes': 1,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g2238727-d4322826-r729731083-Reviews-Phra_Phutthanirokhantarai_Chaiwat_Chaturathit-Phatthalung_City_Phatthalung_Provi.html?m=66827#review729731083',
#     'text': 'พระพุทธนิโรคันตรายชัยวัฒจตุรทิศ หรือพระสี่มุมเมือง ประดิษฐานอยู่หน้าศาลากลางเมืองพัทลุง หากมาเที่ยวพัทลุงแล้วก็ไม่ควรพลาดมาสักการะเพื่อความสิริมงคลแก่ชีวิตและครอบครัว',
#     'title': 'สิ่งศักด์สิทธิ์คู่เมืองพัทลุง',
#     'trip_type': 'NONE',
#     'travel_date': '2019-11-30',
#     'user': {'username': 'Top_pp14',
#      'user_location': {'id': '2238727',
#       'name': 'Phatthalung City, Phatthalung Province'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/f6/7c/01/default-avatar-2020-5.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/f6/7c/01/default-avatar-2020-5.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/f6/7c/01/default-avatar-2020-5.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/1a/f6/7c/01/default-avatar-2020-5.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/f6/7c/01/default-avatar-2020-5.jpg'}},
#     'subratings': {}},
#    {'id': 527059956,
#     'lang': 'th',
#     'location_id': 4322826,
#     'published_date': '2017-09-24T15:03:18Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g2238727-d4322826-r527059956-Reviews-Phra_Phutthanirokhantarai_Chaiwat_Chaturathit-Phatthalung_City_Phatthalung_Provi.html?m=66827#review527059956',
#     'text': 'มาพัทลุงแล้วต้องมากราบพระพุทธนิโรฯ อยู่หน้าศาลากลางจังหวัด\nใครอยากจะมาบนบานอะไรก็เชิญครับท่านรับทั้งหมด',
#     'title': 'พระคู่เมือง',
#     'trip_type': 'เดินทางกับเพื่อน',
#     'travel_date': '2017-09-30',
#     'user': {'username': 'prajuab',
#      'user_location': {'id': 'null'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/f6/eb/a3/default-avatar-2020-38.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/f6/eb/a3/default-avatar-2020-38.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/f6/eb/a3/default-avatar-2020-38.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/1a/f6/eb/a3/default-avatar-2020-38.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/f6/eb/a3/default-avatar-2020-38.jpg'}},
#     'subratings': {}},
#    {'id': 358021116,
#     'lang': 'th',
#     'location_id': 4322826,
#     'published_date': '2016-03-23T22:45:40Z',
#     'rating': 4,
#     'helpful_votes': 1,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s4.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g2238727-d4322826-r358021116-Reviews-Phra_Phutthanirokhantarai_Chaiwat_Chaturathit-Phatthalung_City_Phatthalung_Provi.html?m=66827#review358021116',
#     'text': 'กราบไหว้ขอพรเพื่อเป็นศิริมงคล บนบาลศาลกล่าว เมื่อสมดังใจหมาย สามารถแก้ได้ ทุกวัน อังคาร พฤหัส ศุกร์ มีเจ้าหน้าที่ช่วยเหลือ',
#     'title': 'จุดศูนย์รวมจิตใจชาวพัทลุง',
#     'trip_type': 'ครอบครัว',
#     'travel_date': '2016-03-31',
#     'user': {'username': 'suwitpok127',
#      'user_location': {'id': '2238727',
#       'name': 'Phatthalung City, Phatthalung Province'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/0a/9a/2c/d3/suwitpok127.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/0a/9a/2c/d3/suwitpok127.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/0a/9a/2c/d3/suwitpok127.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-s/0a/9a/2c/d3/suwitpok127.jpg'}},
#     'subratings': {}}]},
#  {'24175951': [{'id': 953079413,
#     'lang': 'th',
#     'location_id': 24175951,
#     'published_date': '2024-05-30T22:39:37Z',
#     'rating': 4,
#     'helpful_votes': 65,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s4.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g2237213-d24175951-r953079413-Reviews-Wat_Phra_Phuttha_Saeng_Tham-Nong_Khae_Saraburi_Province.html?m=66827#review953079413',
#     'text': 'วัดพระพุทธแสงธรรมแห่งนี้ตั้งอยู่ที่ตำบลหนองนาก อำเภอหนองแค จังหวัดสระบุรี หาไม่ยากเลยบริเวณด้านหน้าทางเข้าวัดจะอยู่ติดกับริมถนนสายหลักไม่ต้องขับรถลึกเข้าไปซึ่งบางวัดจะหาทางเข้าหรือทางไปวัดค่อนข้างยาก\n\nเจ้าอาวาสและผู้ที่ริเริ่มสร้างวัดนี้ชื่อว่า พระราชวัชรญาณรังษี เป็นเจ้าคณะจังหวัดสระบุรี(สังกัดธรรมยุต) เป็นชาวหาดใหญ่ จ.สงขลา ท่านเป็นประธานในการก่อสร้างวัดนี้ขึ้นเพื่อไว้สำหรับเป็นศูนย์รวมจิตใจแก่ชาวพุทธและใช้เป็นสถานที่ในการเผยแพร่ศาสนาพุทธให้คงอยู่และสืบต่อไป\n\nโดยวัดนี้มีพื้นที่กว้างมากถึง300กว่าไร่ โดยประมาณ กำลังมีสิ่งปลูกสร้างต่างๆที่สำคัญเพิ่มขึ้นอย่างต่อเนื่อง สถานที่ปฏิบัติธรรมภายในวัดจะมีชื่อว่า "แสงธรรมส่องชีวิต "\n\nสิ่งที่โดดเด่นของสิ่งปลูกสร้างภายในวัด ตั้งแต่แรกเข้าบริเวณเขตวัดท่านจะต้องเห็นสะดุดตาเป็นสิ่งแรกคือโดมยักษ์สแตนเลสขนาดมหึมามีขนาดความสูง 50 เมตร และมีความกว้าง90 เมตร โดยประมาณ รูปทรงคล้ายดอกเห็ดหรือยานอวกาศในมุมมองคนทั่วไป แต่ที่นี่เค้าจะเรียกบริเวณตรงนี้ว่า มหาวิหารทรงบาตรคว่ำ ที่ครอบองค์พระพุทธรูปปางปฐมเทศนาขนาดใหญ่เอาไว้ด้านใน ตอนนี้การก่อสร้างใกล้แล้วเสร็จแล้ว ถ้าเสร็จจะต้องงดงามและยิ่งใหญ่มากๆ\n\nอีกหนึ่งสถานที่ภายในวัดที่แนะนำให้ไปก็คือ พระอุโบสถไม้แดงซึ่งด้านในจะประดิษฐาน พระพุทธรูปปางประทานพรสีขาวมุก ที่พระพักตร์เต็มเปี่ยมด้วยความเมตตาขนาบสองฝั่งด้วยพระยืนปางห้ามสมุทรอยู่ด้านซ้าย และปางแสดงอิทธิปาฏิหาริย์อยู่ด้านขวา เป็นองค์สีขาวล้วนดูสวยงามและสะอาดตา\n\nบริเวณผนังของพระอุโบสถและหลังคาภายในอาคารด้านบนจะประดับด้วยโคมไฟแชนเดอเรียขนาดใหญ่และปีกของหลังคาด้านข้างก็ประดับด้วยโคมไฟขนาดใหญ่ อีกทั้งยังมีงานแกะสลักเป็นกลีบดอกไม้ที่งดงามลงตัว\n\nวัดพระพุทธแสงธรรม เปิดให้พุทธศาสนิกชนเข้าชมทุกวัน ตั้งแต่เวลา 08.00-18.00 น.ครับ',
#     'title': 'ศาสนสถานที่โดดเด่นด้วยโดมยักษ์คล้ายยานอวกาศและมีพระอุโบสถไม้แดงซึ่งด้านในจะประดิษฐาน พระพุทธรูปปางประทานพรสีขาวมุก',
#     'trip_type': 'เดินทางคนเดียว',
#     'travel_date': '2024-05-31',
#     'user': {'username': 'tigerxmen',
#      'user_location': {'id': '293915', 'name': 'Thailand'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/26/de/9b/99/avatar.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/26/de/9b/99/avatar.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/26/de/9b/99/avatar.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-s/26/de/9b/99/avatar.jpg'}},
#     'subratings': {}}]},
#  {'6015313': [{'id': 436835925,
#     'lang': 'th',
#     'location_id': 6015313,
#     'published_date': '2016-11-13T11:38:37Z',
#     'rating': 4,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s4.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g21374629-d6015313-r436835925-Reviews-Wat_Phuttha_Chaiyo-Nong_Kae_Hua_Hin_Prachuap_Khiri_Khan_Province.html?m=66827#review436835925',
#     'text': 'เป็นวัดที่ถือว่ามีชื่อเสียงอีกแห่งของหัวหิน ที่ใครที่ผ่านเส้นทางนี้ อาจต้องแวะเลี้ยวเขาไปกราบไหว้พระที่วัดพุทธไชโยสักครั้ง เป็นที่วัดที่อยู่บนเนินเขาเล็กๆ บรรยากาศปลอดโปร่ง เงียบสงบ เหมาะแก่การทำบุญอย่างยิ่ง',
#     'title': 'วัดบนเนินเขา บรรยากาศดี เงียบสงบ',
#     'trip_type': 'ครอบครัว',
#     'travel_date': '2016-08-31',
#     'user': {'username': 'Mentsang',
#      'user_location': {'id': '297933', 'name': 'Prachuap Khiri Khan Province'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/12/2f/ee/1e/mentsang.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/12/2f/ee/1e/mentsang.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/12/2f/ee/1e/mentsang.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/12/2f/ee/1e/mentsang.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-w/12/2f/ee/1e/mentsang.jpg'}},
#     'subratings': {}},
#    {'id': 377235541,
#     'lang': 'th',
#     'location_id': 6015313,
#     'published_date': '2016-05-28T04:10:13Z',
#     'rating': 5,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s5.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g21374629-d6015313-r377235541-Reviews-Wat_Phuttha_Chaiyo-Nong_Kae_Hua_Hin_Prachuap_Khiri_Khan_Province.html?m=66827#review377235541',
#     'text': 'เป็นวัดที่ชอบไปถวายสังฆทาน หลวงพ่อ และ พระที่วัดนี้ ท่านสำรวม และเวลาไปถ่ายสังฆทาน ท่านก็สวดให้พรเราอย่างน่าเลื่อมใส',
#     'title': 'เป็นวัดที่ชอบไปถวายสังฆทาน',
#     'trip_type': 'NONE',
#     'travel_date': '2016-05-31',
#     'user': {'username': 'Phatjang',
#      'user_location': {'id': '297922',
#       'name': 'Hua Hin, Prachuap Khiri Khan Province'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/0b/a7/0e/ec/phatjang.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/0b/a7/0e/ec/phatjang.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/0b/a7/0e/ec/phatjang.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-o/0b/a7/0e/ec/phatjang.jpg'}},
#     'subratings': {}},
#    {'id': 319240910,
#     'lang': 'th',
#     'location_id': 6015313,
#     'published_date': '2015-10-16T05:55:42Z',
#     'rating': 4,
#     'helpful_votes': 0,
#     'rating_image_url': 'https://www.tripadvisor.com/img/cdsi/img2/ratings/traveler/s4.0-66827-5.svg',
#     'url': 'https://www.tripadvisor.com/ShowUserReviews-g21374629-d6015313-r319240910-Reviews-Wat_Phuttha_Chaiyo-Nong_Kae_Hua_Hin_Prachuap_Khiri_Khan_Province.html?m=66827#review319240910',
#     'text': 'ไปเที่ยวที่ไหนก็ต้องแวะวัดที่ครั้ง วัดพุทธไชโยก็เป็นอีก 1 วัดที่ได้มีโอกาศเข้าไปกราบพระ สงบเงียบ บรรยากาศดี',
#     'title': 'เข้าวัดพุทธไชโย',
#     'trip_type': 'ครอบครัว',
#     'travel_date': '2015-07-31',
#     'user': {'username': 'pimnara_sine',
#      'user_location': {'id': '293916', 'name': 'Bangkok'},
#      'avatar': {'thumbnail': 'https://media-cdn.tripadvisor.com/media/photo-t/1a/f6/f0/9f/default-avatar-2020-16.jpg',
#       'small': 'https://media-cdn.tripadvisor.com/media/photo-l/1a/f6/f0/9f/default-avatar-2020-16.jpg',
#       'medium': 'https://media-cdn.tripadvisor.com/media/photo-f/1a/f6/f0/9f/default-avatar-2020-16.jpg',
#       'large': 'https://media-cdn.tripadvisor.com/media/photo-p/1a/f6/f0/9f/default-avatar-2020-16.jpg',
#       'original': 'https://media-cdn.tripadvisor.com/media/photo-o/1a/f6/f0/9f/default-avatar-2020-16.jpg'}},
#     'subratings': {}}]},
#  ...]

# %%
len(combined_reviews_data)
# Out:
# 1521

# %%
tripadvisor_central_attraction_locations = pd.read_csv("../dataset/locations/TripAdvisor_Location_Ids.csv")
tripadvisor_central_attraction_locations
# Out:
#       Unnamed: 0  location_id  \
# 0              0      2209612
# 1              1      2273363
# 2              2       311043
# 3              3       317504
# 4              4       456322
# ...          ...          ...
# 1899        6905     13009981
# 1900        6906      3256228
# 1901        6907      2515972
# 1902        6911     13365103
# 1903        6912      2645868
#
#                                                  name         province  \
# 0                                    Wat Ratchabophit          Bangkok
# 1     Wat Rajapradit Sathitmahasimaram Rajaworavihara          Bangkok
# 2                                  Wat Phra Chetuphon          Bangkok
# 3                           Temple Of Dawn (Wat Arun)          Bangkok
# 4                                           Wat Umong          Bangkok
# ...                                               ...              ...
# 1899                               Thai Sabai Massage  Samut Songkhram
# 1900                          Phuket Dragon Muay Thai  Samut Songkhram
# 1901                       Thai Cooking School Phuket  Samut Songkhram
# 1902                     Nong Bua Thai Dessert Market  Samut Songkhram
# 1903                     Free Thai (Seri Thai) Museum  Samut Songkhram
#
#        place_id
# 0     P03013220
# 1     P03013220
# 2     P03013220
# 3     P03013220
# 4     P03013220
# ...         ...
# 1899  P03012297
# 1900  P03012297
# 1901  P03012297
# 1902  P03000251
# 1903  P03000251
#
# [1904 rows x 5 columns]

# %%
normalize_reviews_data = pd.DataFrame()

for location_data in combined_reviews_data:
    for location_id, reviews in location_data.items():
        print(f"Location ID: {location_id}")

        # Iterate over each review in the list of reviews
        for review in reviews:
            # Create a DataFrame for each review
            review_df = pd.DataFrame([{
                "helpful_votes": review.get("helpful_votes", 0),
                "location_id": review.get("location_id", None),
                "lang": review.get("lang", None),
                "review_id": review.get("id", None),
                "review": review.get("text", None),
                "review_subject": review.get("title", None),
                "trip_type": review.get("trip_type", None),
                "travel_date": review.get("travel_date", None),
                "rating": review.get("rating", 0)
            }])

            # Concatenate the current review DataFrame with the normalized DataFrame
            normalize_reviews_data = pd.concat([normalize_reviews_data, review_df], ignore_index=True)

normalize_reviews_data.replace("None", None, inplace=True)

# %%
normalize_reviews_data
# Out:
#       helpful_votes  location_id lang  review_id  \
# 0                 0      2209612   th  922231809
# 1                18      2209612   th  777982512
# 2                 0      2209612   th  738367222
# 3                 2      2209612   th  737450116
# 4                 0      2209612   th  690288478
# ...             ...          ...  ...        ...
# 6081              0      2645868   th  495275277
# 6082              0      2645868   th  437755007
# 6083              0      2645868   th  361116911
# 6084              0      2645868   th  332354742
# 6085              0      2645868   th  245695590
#
#                                                  review  \
# 0     เป็นวัดที่สร้างขึ้นในรัชกาลที่ 5 \nพระบาทสมเด็...
# 1     ตั้งอยู่ด้านทิศตะวันตกของวัด มีประตูเข้าตรงทาง...
# 2     วันนี้เป็นที่พำนักของพระสังฆราชองค์ใหม่ ตอนไปก...
# 3     วันนี้เป็นบุญของครอบครัวเราแท้ๆมีโอกาส ได้เข้า...
# 4     พอดีมาแถว ถ.เฟื่องนครเลยได้แวะมาวัดนี้ ตอนกลาง...
# ...                                                 ...
# 6081  เป็นอาคารเชิงประวัติศาสตร์ ตั้งอยู่หลังโรงแรมภ...
# 6082  เป็นสถานที่ที่รวบรวมข้อมูล เอกสาร สิ่งของ ต่าง...
# 6083  สถานที่รวบรมประวัติการดำเนินงานของผู้กล้าที่ทำ...
# 6084  การมาท่องเที่ยวที่นี่ เราจะได้เรียนรู้ถึงเรื่อ...
# 6085  ปกติตรงนั้นจะมีโรงแรมภรดร ครับถือโอกาสใกล้ที่พ...
#
#                      review_subject         trip_type travel_date  rating
# 0        วัดราชบพิตร สถิตมหาสีมาราม          ครอบครัว  2023-10-31       5
# 1                       ชมสุสานหลวง  เดินทางกับเพื่อน  2020-11-30       5
# 2                           ไหว้พระ            คู่รัก  2019-12-31       5
# 3      กราบสักการะ สมเด็จพระสังฆราช              NONE  2019-12-31       5
# 4                        วัดราชบพิธ          ครอบครัว  2019-07-31       4
# ...                             ...               ...         ...     ...
# 6081             บ้านเสรีไทย จ.แพร่    เดินทางคนเดียว  2017-06-30       5
# 6082                 รวบรวมของโบราณ            คู่รัก  2016-11-30       3
# 6083              ระลึกถึงความดีงาม              NONE  2016-03-31       5
# 6084  พิพิธภัณฑ์เสรีไทย จังหวัดแพร่    เดินทางคนเดียว  2015-11-30       4
# 6085                 พักที่เดียวกัน          ครอบครัว  2014-11-30       3
#
# [6086 rows x 9 columns]

# %%
merged_df = normalize_reviews_data.merge(tripadvisor_central_attraction_locations[['location_id', 'name', 'province', 'place_id']], on='location_id', how='left')

# Rename the 'name' column to 'location_name'
merged_df.rename(columns={'name': 'location_name'}, inplace=True)
len(merged_df)
# Out:
# 6086

# %%
merged_df.to_csv("../dataset/TripAdvisor_reviews_TH.csv")
# EN_tripadvisor_reviews = pd.read_csv("dataset/TripAdvisor_reviews_EN.csv")

# %%
# Define Thai stop words
thai_stopwords = thai_stopwords()

# Function to normalize text
def normalize_text(text):
    tokens = word_tokenize(text, engine='newmm')
    tokens = [token for token in tokens if token not in thai_stopwords and token.isalpha()]
    return ' '.join(tokens)

# %%
thai_stopwords
# Out:
# frozenset({'ทุกที่',
#            'รับ',
#            'ยืนนาน',
#            'ช่วงหลัง',
#            'มอง',
#            'โดย',
#            'ที่ว่า',
#            'นับจากนั้น',
#            'ประการฉะนี้',
#            'แล้วแต่',
#            'ยังจะ',
#            'ตลอดทั่ว',
#            'เขียน',
#            'เป็นแต่',
#            'ทีไร',
#            'สิ่งไหน',
#            'ถึงเมื่อไร',
#            'สมัยโน้น',
#            'เช่นก่อน',
#            'แต่อย่างใด',
#            'เพียงแต่',
#            'คล้ายกับว่า',
#            'จัดทำ',
#            'ถึงอย่างไร',
#            'ได้',
#            'แห่งไหน',
#            'นู่น',
#            'คล้าย',
#            'มัน',
#            'จนกว่า',
#            'เหล่านี้',
#            'ครั้งไหน',
#            'วันนั้น',
#            'เช่นที่ว่า',
#            'เนี่ยเอง',
#            'นับจากนี้',
#            'เกี่ยวกัน',
#            'ณ',
#            'จัด',
#            'ถึงแม้จะ',
#            'แต่เพียง',
#            'ประสบ',
#            'ต่าง',
#            'มา',
#            'พวกเธอ',
#            'ยืนยง',
#            'แรก',
#            'นับแต่นี้',
#            'ทุกวัน',
#            'ในช่วง',
#            'สั้นๆ',
#            'สบาย',
#            'ถูกต้อง',
#            'รึ',
#            'แค่',
#            'นับแต่',
#            'ไกล',
#            'พร้อมทั้ง',
#            'นาน',
#            'เกือบ',
#            'กันเอง',
#            'ตลอดทั่วถึง',
#            'เสร็จสมบูรณ์',
#            'รวด',
#            'ก่อน',
#            'ง่ายๆ',
#            'ราย',
#            'บน',
#            'ด้วย',
#            'ทั้งหลาย',
#            'สิ่งนี้',
#            'ถึงบัดนั้น',
#            'ความ',
#            'ใคร',
#            'พอกัน',
#            'เสมือนว่า',
#            'อย่างไรเสีย',
#            'พอแล้ว',
#            'เฉกเช่น',
#            'มั้ยนะ',
#            'เพียงใด',
#            'ประกอบ',
#            'เกี่ยวข้อง',
#            'ด้วยเหมือนกัน',
#            'ไม่',
#            'ต่างหาก',
#            'ใครๆ',
#            'เพราะ',
#            'นํา',
#            'ต่อ',
#            'นั่นแหละ',
#            'ก็แล้วแต่',
#            'เหตุนี้',
#            'เข้า',
#            'ดังกับ',
#            'เสร็จแล้ว',
#            'แต่เมื่อ',
#            'อีก',
#            'ทุกทาง',
#            'ประมาณ',
#            'หน่อย',
#            'ส่วนนั้น',
#            'ให้แก่',
#            'เมื่อคราวที่',
#            'ก็ตามที',
#            'เช่นดังที่',
#            'ถึงจะ',
#            'รวมถึง',
#            'จนเมื่อ',
#            'เถิด',
#            'อย่าง',
#            'รวดเร็ว',
#            'จนขณะนี้',
#            'หมดกัน',
#            'คราวหลัง',
#            'มุ่งหมาย',
#            'เสียก่อน',
#            'ทุกชิ้น',
#            'ครั้งหนึ่ง',
#            'แท้',
#            'ด้วยที่',
#            'ก็',
#            'ปรับ',
#            'ก่อนๆ',
#            'จำ',
#            'ด้าน',
#            'ร่วม',
#            'พวกท่าน',
#            'เป็น',
#            'แห่งนี้',
#            'ร่วมมือ',
#            'ประการใด',
#            'เนี่ย',
#            'ยิ่งจน',
#            'น่ะ',
#            'เดียว',
#            'ทีเดียว',
#            'นู้น',
#            'แต่ก็',
#            'พวกกู',
#            'ได้มา',
#            'หรือไม่',
#            'ไกลๆ',
#            'เช่นใด',
#            'แค่เพียง',
#            'ถูก',
#            'มองว่า',
#            'จับ',
#            'ช่วงแรก',
#            'เป็นที',
#            'ส่วนดี',
#            'เกี่ยวๆ',
#            'จรดกับ',
#            'คราวโน้น',
#            'นี่แน่ะ',
#            'เล่าว่า',
#            'พวกฉัน',
#            'ทั้งปวง',
#            'เผื่อที่',
#            'ถึงเมื่อ',
#            'พร้อมที่',
#            'ตลอดจน',
#            'หลัง',
#            'อาจ',
#            'นะ',
#            'ๆ',
#            'แล้ว',
#            'ย่อย',
#            'เรียบ',
#            'แต่ละ',
#            'อย่างดี',
#            'เสียนั่น',
#            'คงจะ',
#            'เป็นๆ',
#            'ก่อนหน้านี้',
#            'กันเถอะ',
#            'เห็นแก่',
#            'นาย',
#            'แห่งนั้น',
#            'เต็มไปหมด',
#            'ช้าๆ',
#            'ทั้งนั้น',
#            'นอกจากว่า',
#            'ระยะๆ',
#            'ซะก่อน',
#            'เมื่อคราว',
#            'ร่วมกัน',
#            'เสียยิ่งนัก',
#            'ใน',
#            'พอสมควร',
#            'ที่ได้',
#            'สมัยก่อน',
#            'ค่ะ',
#            'นอกจากนี้',
#            'ใช่ไหม',
#            'ใช่',
#            'นานๆ',
#            'จริงจัง',
#            'ยอม',
#            'ตลอดมา',
#            'เชื่อถือ',
#            'พอๆ',
#            'ทีใด',
#            'นับตั้งแต่',
#            'มึง',
#            'ใคร่',
#            'นั้นๆ',
#            'เปลี่ยน',
#            'เป็นแต่เพียง',
#            'ได้ที่',
#            'สิ่งใด',
#            'จนกระทั่ง',
#            'ก็ได้',
#            'เพราะฉะนั้น',
#            'เสียจน',
#            'รวมด้วย',
#            'ตามที่',
#            'เข้าใจ',
#            'ตรง',
#            'ใหญ่ๆ',
#            'หลังจาก',
#            'จด',
#            'ครา',
#            'คุณ',
#            'หารือ',
#            'กว้างๆ',
#            'กระนั้น',
#            'ทั้งสิ้น',
#            'ขณะเดียวกัน',
#            'พอควร',
#            'ก็แค่',
#            'ล่าสุด',
#            'อย่างไรก็ได้',
#            'จากนั้น',
#            'เป็นที่',
#            'จวนจะ',
#            'สูงกว่า',
#            'ครานี้',
#            'ที่ละ',
#            'นั่นไง',
#            'บางคราว',
#            'โตๆ',
#            'เช่น',
#            'หนึ่ง',
#            'ซึ่งได้แก่',
#            'จริง',
#            'หากแม้น',
#            'ทันทีทันใด',
#            'เมื่อนี้',
#            'บอกว่า',
#            'เกิน',
#            'ยังคง',
#            'ถึงแก่',
#            'แล้วกัน',
#            'แต่ทว่า',
#            'นี้เอง',
#            'จ๋า',
#            'ค่อย',
#            'ทํา',
#            'ผู้ใด',
#            'เช่นดัง',
#            'อาจเป็นด้วย',
#            'เสีย',
#            'เผื่อจะ',
#            'ยังแต่',
#            'แม้',
#            'ทำให้',
#            'ซึ่งๆ',
#            'พอจะ',
#            'บางกว่า',
#            'เพียงไหน',
#            'ลง',
#            'ส่วน',
#            'ทําให้',
#            'พึ่ง',
#            'เมื่อใด',
#            'กลับ',
#            'ยาก',
#            'ช่วงนี้',
#            'มั้ยเนี่ย',
#            'เรื่อยๆ',
#            'อาจจะ',
#            'นอกจากที่',
#            'พอ',
#            'เช่นดังก่อน',
#            'จนถึง',
#            'ไง',
#            'ปิด',
#            'อย่างใด',
#            'การ',
#            'ยิ่งนัก',
#            'ก็ต่อเมื่อ',
#            'ภายภาคหน้า',
#            'เช่นที่เคย',
#            'เมื่อวันวาน',
#            'บ่อยกว่า',
#            'ที่แห่งนั้น',
#            'รวมๆ',
#            'เล็ก',
#            'ครั้งครา',
#            'เชื่อ',
#            'ดั่งเคย',
#            'คิดว่า',
#            'ยิ่งเมื่อ',
#            'วันใด',
#            'ทุกเมื่อ',
#            'จัดหา',
#            'กล่าวคือ',
#            'เสียจนกระทั่ง',
#            'อันเนื่องมาจาก',
#            'ตลอดกาล',
#            'เสร็จสิ้น',
#            'ยิ่งจะ',
#            'เช่นเดียวกับ',
#            'แต่เดิม',
#            'สมัยนี้',
#            'เนื่องจาก',
#            'แต่จะ',
#            'จ้ะ',
#            'ทีเถอะ',
#            'เท่านี้',
#            'คราวไหน',
#            'เสียนี่',
#            'ข้างล่าง',
#            'เมื่อก่อน',
#            'นำพา',
#            'ระยะ',
#            'สูง',
#            'แต่ไหน',
#            'ได้แก่',
#            'แก่',
#            'ไม่ค่อยจะ',
#            'ทันที',
#            'นั่นเอง',
#            'ครั้งนั้น',
#            'ยิ่งใหญ่',
#            'เยอะแยะ',
#            'พอที',
#            'บัดนั้น',
#            'ด้วยประการฉะนี้',
#            'ประการ',
#            'ไหน',
#            'มั้ย',
#            'เคย',
#            'ครั้ง',
#            'เสมือนกับ',
#            'นั่น',
#            'เท่านั้น',
#            'แล้วเสร็จ',
#            'ทำๆ',
#            'พวกกัน',
#            'เต็มๆ',
#            'ใคร่จะ',
#            'ทว่า',
#            'ช้า',
#            'เสียจนถึง',
#            'กระผม',
#            'ช่วงๆ',
#            'เป็นอันมาก',
#            'เมื่อครั้ง',
#            'ตลอดศก',
#            'สิ่ง',
#            'ค่อนข้างจะ',
#            'ทั้งนั้นเพราะ',
#            'บางครั้ง',
#            'หน',
#            'พื้นๆ',
#            'ด้วยว่า',
#            'นี่เอง',
#            'กันดีไหม',
#            'มี',
#            'อย่างไร',
#            'จวนเจียน',
#            'ตลอดวัน',
#            'จำพวก',
#            'เป็นเพียง',
#            'ขั้น',
#            'ตลอดถึง',
#            'จัดงาน',
#            'ยืนยัน',
#            'เห็นควร',
#            'ล้วนแต่',
#            'กลุ่ม',
#            'สืบเนื่อง',
#            'มุ่ง',
#            'ยิ่งแล้ว',
#            'ตนเอง',
#            'บางที่',
#            'ส่วนน้อย',
#            'นั้นไว',
#            'ถึงแม้ว่า',
#            'เช่นนั้นเอง',
#            'รือว่า',
#            'รึว่า',
#            'จึงเป็น',
#            'แม้แต่',
#            'นี้',
#            'วัน',
#            'ดังเก่า',
#            'มักจะ',
#            'ค่อยไปทาง',
#            'พา',
#            'นั่นเป็น',
#            'มั๊ย',
#            'นางสาว',
#            'พอดี',
#            'นอกเหนือจาก',
#            'กลุ่มก้อน',
#            'ว่า',
#            'คุณๆ',
#            'ทีละ',
#            'หมดสิ้น',
#            'กว้างขวาง',
#            'อันละ',
#            'ถึง',
#            'มันๆ',
#            'ค่อยๆ',
#            'ที่นั้น',
#            'ควร',
#            'ก่อนหน้า',
#            'คิด',
#            'ตลอด',
#            'ตลอดกาลนาน',
#            'แม้กระทั่ง',
#            'เฉยๆ',
#            'เพียง',
#            'นี่',
#            'ไร',
#            'แต่ก่อน',
#            'ครัน',
#            'อันๆ',
#            'คราวนี้',
#            'คราวหนึ่ง',
#            'ครานั้น',
#            'เต็มไปด้วย',
#            'เมื่อครั้งก่อน',
#            'ร่วมด้วย',
#            'แสดงว่า',
#            'อันจะ',
#            'ทุกวันนี้',
#            'อื่น',
#            'ไฉน',
#            'รับรอง',
#            'คล้ายกับ',
#            'ครั้งหลัง',
#            'เห็นจะ',
#            'ข้างต้น',
#            'อื่นๆ',
#            'ที่ๆ',
#            'แค่นี้',
#            'พยายาม',
#            'นอกนั้น',
#            'แบบ',
#            'ขณะนี้',
#            'ทุกคราว',
#            'เฉย',
#            'กันนะ',
#            'เธอ',
#            'มุ่งเน้น',
#            'ปรากฏ',
#            'เท่ากัน',
#            'หาก',
#            'เอา',
#            'เหล่า',
#            'ยอมรับ',
#            'ใดๆ',
#            'จนทั่ว',
#            'ทุกสิ่ง',
#            'ยิ่งขึ้น',
#            'ผ่านๆ',
#            'ไม่เป็นไร',
#            'กว้าง',
#            'นำ',
#            'คล้ายกันกับ',
#            'จรด',
#            'เปลี่ยนแปลง',
#            'อัน',
#            'คราวๆ',
#            'จากนี้',
#            'ยังงี้',
#            'ยังโง้น',
#            'ช่วงหน้า',
#            'บอก',
#            'เพิ่มเติม',
#            'ทันใดนั้น',
#            'ซึ่งกันและกัน',
#            'พบว่า',
#            'ใต้',
#            'ง่าย',
#            'จึง',
#            'ซึ่งก็',
#            'นี้แหล่',
#            'ข้างๆ',
#            'แค่ว่า',
#            'ภายหลัง',
#            'ช่วง',
#            'ทุกอย่าง',
#            'ชาว',
#            'ทุกครา',
#            'ฉะนั้น',
#            'ปัจจุบัน',
#            'วันไหน',
#            'รวมทั้ง',
#            'เสียด้วย',
#            'เป็นอันๆ',
#            'ใกล้',
#            'ขณะหนึ่ง',
#            'ถือ',
#            'คือ',
#            'ตั้ง',
#            'นี่นา',
#            'พร้อมกัน',
#            'จ๊ะ',
#            'แค่ไหน',
#            'แห่ง',
#            'ฯลฯ',
#            'ค่อน',
#            'ผล',
#            'ซะจนถึง',
#            'เกือบๆ',
#            'ก็ตามแต่',
#            'อย่างละ',
#            'ข้าพเจ้า',
#            'ทุกๆ',
#            'ซึ่งกัน',
#            'ดังกล่าว',
#            'เขา',
#            'กลุ่มๆ',
#            'เฉพาะ',
#            'ถูกๆ',
#            'ที่สุด',
#            'เยอะ',
#            'แต่ต้อง',
#            'ทัน',
#            'ครับ',
#            'ไป่',
#            'ใหม่ๆ',
#            'ตลอดปี',
#            'ดั่ง',
#            'สิ่งนั้น',
#            'เป็นเพียงว่า',
#            'ทีๆ',
#            'ให้',
#            'คราวละ',
#            'เพียงแค่',
#            'นอก',
#            'ผ่าน',
#            'น้อยกว่า',
#            'เปิด',
#            'เพียงเพื่อ',
#            'ตรงๆ',
#            'จวบ',
#            'รวม',
#            'ไป',
#            'คราหนึ่ง',
#            'ครบถ้วน',
#            'ยิ่ง',
#            'บัดดล',
#            'ขณะนั้น',
#            'ทุก',
#            'เหลือเกิน',
#            'ช่วงถัดไป',
#            'จัดแจง',
#            'อย่างไหน',
#            'จัดตั้ง',
#            'คราวหน้า',
#            'แก้ไข',
#            'กระทั่ง',
#            'แยะ',
#            'ค่อนมาทาง',
#            'ที่แท้จริง',
#            'ยังไง',
#            'เช่นดังว่า',
#            'นักๆ',
#            'พึง',
#            'สมัย',
#            'ยิ่งขึ้นไป',
#            'คราที่',
#            'ส่วนใหญ่',
#            'หรือเปล่า',
#            'เช่นเคย',
#            'อะไร',
#            'พวกคุณ',
#            'ปฏิบัติ',
#            'ซะจน',
#            'ต่อกัน',
#            'จาก',
#            'ทรง',
#            'จวบจน',
#            'พวกโน้น',
#            'ขอ',
#            'นี่แหละ',
#            'ที่จริง',
#            'แต่ไร',
#            '\ufeffๆ',
#            'อันไหน',
#            'ผิด',
#            'เผื่อว่า',
#            'ภายภาค',
#            'อย่างที่',
#            'นิดหน่อย',
#            'เป็นดัง',
#            'หรือ',
#            'นอกจาก',
#            'เพื่อที่จะ',
#            'ทั้ง',
#            'พร้อมเพียง',
#            'เช่นเมื่อ',
#            'พวกที่',
#            'ขาด',
#            'ครบ',
#            'ไหนๆ',
#            'เมื่อเย็น',
#            'สู่',
#            'เท่าไหร่',
#            'ในที่',
#            'อยาก',
#            'คล้ายกัน',
#            'ให้มา',
#            'ทุกครั้ง',
#            'ขวางๆ',
#            'รือ',
#            'ด้วยเช่นกัน',
#            'เร็วๆ',
#            'พวกนี้',
#            'น้อย',
#            'ถึงบัดนี้',
#            'สั้น',
#            'ตามๆ',
#            'เป็นอาทิ',
#            'แม้ว่า',
#            'กัน',
#            'แค่จะ',
#            'เช่นนี้',
#            'เรียก',
#            'ถ้าหาก',
#            'ยังงั้น',
#            'ซึ่งก็คือ',
#            'มัก',
#            'ย่อม',
#            'ภาย',
#            'บางครา',
#            'บางแห่ง',
#            'เป็นอัน',
#            'เช่นเดียวกัน',
#            'ที่ไหน',
#            'ครบครัน',
#            'เห็น',
#            'ก็ตาม',
#            'จนแม้น',
#            'จะ',
#            'แม้นว่า',
#            'มาก',
#            'ทั้งคน',
#            'ด้วยเหตุเพราะ',
#            'จังๆ',
#            'ทั้งที',
#            'จง',
#            'อย่างๆ',
#            'พร้อมกับ',
#            'ไม่ค่อย',
#            'ขวาง',
#            'กำลัง',
#            'ก็คือ',
#            'ดังเคย',
#            'ต้อง',
#            'เท่าใด',
#            'ขณะใดๆ',
#            'ครั้งที่',
#            'เน้น',
#            'กับ',
#            'ยืนยาว',
#            'ทุกหน',
#            'เกินๆ',
#            'บางๆ',
#            'จนตลอด',
#            'จ้า',
#            'สูงส่ง',
#            'ปรากฏว่า',
#            'พอเหมาะ',
#            'เสียนั่นเอง',
#            'เช่นนั้น',
#            'เผื่อ',
#            'กระทำ',
#            'ยก',
#            'นาง',
#            'จู่ๆ',
#            'หาความ',
#            'แต่ถ้า',
#            'คล้ายว่า',
#            'ทั้งนี้',
#            'ซึ่ง',
#            'ดั่งเก่า',
#            'ดั่งกับว่า',
#            'ให้ไป',
#            'สูงสุด',
#            'ข้า',
#            'นับแต่ที่',
#            'ซะจนกระทั่ง',
#            'ครั้งกระนั้น',
#            'ทั้งตัว',
#            'บาง',
#            'เลย',
#            'ทั้งเป็น',
#            'มิได้',
#            'ไม่ว่า',
#            'อันที่',
#            'ส่วนเกิน',
#            'เป็นด้วย',
#            'คงอยู่',
#            'สมัยนั้น',
#            'เพื่อให้',
#            'เกี่ยวกับ',
#            'ยาวนาน',
#            'ให้ดี',
#            'บัดนี้',
#            'ขณะที่',
#            'เมื่อคราวก่อน',
#            'ได้รับ',
#            'จัดการ',
#            'เท่า',
#            'นับแต่นั้น',
#            'พูด',
#            'สุด',
#            'จัง',
#            'ที่',
#            'นัก',
#            'ส่วนที่',
#            'เป็นการ',
#            'อนึ่ง',
#            'พอสม',
#            'เช่นไร',
#            'มั้ยนั่น',
#            'เป็นต้นไป',
#            'ฝ่ายใด',
#            'เกือบจะ',
#            'ทั่ว',
#            'หลาย',
#            'ตลอดทั้ง',
#            'เช่นดังเก่า',
#            'กันไหม',
#            'ครั้งๆ',
#            'ฉะนี้',
#            'เช่นที่',
#            'เป็นเพราะ',
#            'จัดให้',
#            'นิด',
#            'อย่างเดียว',
#            'แต่',
#            'พวก',
#            'หรือไง',
#            'จากนี้ไป',
#            'ออก',
#            'เป็นเพราะว่า',
#            'อย่างไรก็',
#            'นิดๆ',
#            'ดั่งกับ',
#            'เปิดเผย',
#            'นำมา',
#            'เคยๆ',
#            'หากแม้นว่า',
#            'คราไหน',
#            'เร็ว',
#            'นอกจากนั้น',
#            'เมื่อเช้า',
#            'ถือว่า',
#            'ข้าฯ',
#            'ได้แต่',
#            'ต่างก็',
#            'ทุกที',
#            'พอเพียง',
#            'อย่างนี้',
#            'เป็นต้น',
#            'อย่างน้อย',
#            'แสดง',
#            'มากกว่า',
#            'ขณะใด',
#            'อย่างเช่น',
#            'เยอะๆ',
#            'เกิด',
#            'เมื่อไหร่',
#            'ใหญ่โต',
#            'อันใด',
#            'ช่วงที่',
#            'เมื่อไร',
#            'เล็กน้อย',
#            'ยกให้',
#            'อันได้แก่',
#            'ทั้งนั้นด้วย',
#            'อดีต',
#            'ภาค',
#            'จะได้',
#            'แต่ที่',
#            'ยาว',
#            'สิ้น',
#            'กว่า',
#            'ก็จะ',
#            'ทุกตัว',
#            'คราวที่',
#            'ละ',
#            'เพียงเพราะ',
#            'เรา',
#            'สุดๆ',
#            'ซะ',
#            'ช้านาน',
#            'ไม่ใช่',
#            'ครั้งใด',
#            'ประการหนึ่ง',
#            'ฝ่าย',
#            'เหลือ',
#            'บ่อย',
#            'แท้จริง',
#            'ถ้าจะ',
#            'รวมกัน',
#            'ภายใน',
#            'นี่ไง',
#            'เสร็จ',
#            'จริงๆจังๆ',
#            'เมื่อ',
#            'ทั้งที่',
#            'ภายใต้',
#            'พวกนู้น',
#            'เสร็จกัน',
#            'อยู่',
#            'เอ็ง',
#            'ตลอดไป',
#            'เช่นกัน',
#            'เสียแล้ว',
#            'คราวใด',
#            'เพียงพอ',
#            'มีแต่',
#            'หากแม้',
#            'บางที',
#            'บัดเดี๋ยวนี้',
#            'ผิดๆ',
#            'แห่งโน้น',
#            'เป็นอันว่า',
#            'ด้วยกัน',
#            'คราวนั้น',
#            'แห่งใด',
#            'ช่วงระหว่าง',
#            'ข้าง',
#            'ฯล',
#            'เพื่อที่',
#            'จนบัดนี้',
#            'ด้วยเพราะ',
#            'บางขณะ',
#            'ทั้งมวล',
#            'ตนฯ',
#            'สูงๆ',
#            'ทั้งๆ',
#            'มิ',
#            'เพื่อ',
#            'ทุกแห่ง',
#            'พอที่',
#            'ทำไร',
#            'ในเมื่อ',
#            'ช่วย',
#            'มั้ยล่ะ',
#            'เล็กๆ',
#            'ทุกอัน',
#            'แต่ว่า',
#            'ค่อนข้าง',
#            'เพียงไร',
#            'ด้วยเหตุที่',
#            'ส่วนด้อย',
#            'หนอย',
#            'ดังกับว่า',
#            'ครั้งหลังสุด',
#            'ทำไม',
#            'ใหม่',
#            'ล้วนจน',
#            'เชื่อว่า',
#            'เมื่อนั้น',
#            'อาจเป็น',
#            'เหตุนั้น',
#            'เหล่านั้น',
#            'ฉัน',
#            'อันที่จริง',
#            'ถ้า',
#            'ส่ง',
#            'และ',
#            'ตามแต่',
#            'ช่วงท้าย',
#            'เรื่อย',
#            'เมื่อคืน',
#            'กันดีกว่า',
#            'ต่างๆ',
#            'เท่าไร',
#            'เกี่ยวเนื่อง',
#            'มากมาย',
#            'เหตุ',
#            'ไม่ค่อยเป็น',
#            'เอง',
#            'อย่างนั้น',
#            'ด้วยเหตุว่า',
#            'คะ',
#            'น่า',
#            'คราว',
#            'ใช้',
#            'ที่ใด',
#            'พอตัว',
#            'บ่อยๆ',
#            'ยัง',
#            'เท่าที่',
#            'ครั้งก่อน',
#            'บ่อยครั้ง',
#            'ในระหว่าง',
#            'ตลอดทั่วทั้ง',
#            'ทุกคน',
#            'เพิ่ง',
#            'กล่าว',
#            'เพิ่ม',
#            'ครั้งนี้',
#            'พบ',
#            'ถึงแม้',
#            'แค่นั้น',
#            'ด้วยเหตุนั้น',
#            'ที',
#            'พวกเขา',
#            'เชื่อมั่น',
#            'ที่นี้',
#            'หนอ',
#            'แต่นั้น',
#            'นั้น',
#            'บอกแล้ว',
#            'หรือยัง',
#            'ทั้งหมด',
#            'ฯ',
#            'เป็นต้นมา',
#            'ใกล้ๆ',
#            'อันที่จะ',
#            'เพื่อว่า',
#            'เพิ่งจะ',
#            'สิ้นกาลนาน',
#            'อย่างยิ่ง',
#            'หมด',
#            'ภายนอก',
#            'ภาคฯ',
#            'ให้แด่',
#            'เมื่อวาน',
#            'สําหรับ',
#            'คราใด',
#            'กันและกัน',
#            'แยะๆ',
#            'ก็ดี',
#            'ภายหน้า',
#            'จำเป็น',
#            'เท่ากับ',
#            'ทาง',
#            'ขณะ',
#            'บ้าง',
#            'คำ',
#            'กำหนด',
#            'จนแม้',
#            'ที่ซึ่ง',
#            'มิใช่',
#            'ส่วนมาก',
#            'เริ่ม',
#            'มิฉะนั้น',
#            'ข้างเคียง',
#            'โต',
#            'หาใช่',
#            'สามารถ',
#            'ส่วนใด',
#            'เห็นว่า',
#            'อย่างมาก',
#            'อย่างหนึ่ง',
#            'เพราะว่า',
#            'พร้อมด้วย',
#            'จวน',
#            'นับ',
#            'ยิ่งกว่า',
#            'จริงๆ',
#            'ช่วงก่อน',
#            'กำลังจะ',
#            'ช่วงนั้น',
#            'จวบกับ',
#            'แหละ',
#            'ช่วงต่อไป',
#            'ผู้',
#            'ล้วน',
#            'ที่แล้ว',
#            'เหตุผล',
#            'น้อยๆ',
#            'พวกมึง',
#            'เสียนี่กระไร',
#            'หากว่า',
#            'เป็นเพื่อ',
#            'จน',
#            'พร้อม',
#            'ที่แท้',
#            'เราๆ',
#            'ไว้',
#            'เก็บ',
#            'ตลอดระยะเวลา',
#            'ตน',
#            'ด้วยเหตุนี้',
#            'พวกมัน',
#            'สำคัญ',
#            ...})

# %%
from pythainlp import word_tokenize
from pythainlp.util import normalize
from string import punctuation

# %%
def preprocess_thai_text(text):
    # Normalize the text (e.g., harmonizing character representations)
    text = normalize(text)

    # Lowercasing (Thai text does not differentiate case, but we include for consistency)
    text = text.lower()

    # Removing punctuation
    thai_punctuation = punctuation + 'ๆฯ'  # Extend punctuation to include common Thai characters
    text = text.translate(str.maketrans('', '', thai_punctuation))

    # Tokenization (Thai-specific tokenization)
    tokens = word_tokenize(text, engine='newmm')  # 'newmm' is a recommended tokenizer

    # # Removing stopwords
    # thai_stopwords = set(stopwords.words('thai'))
    tokens = [word for word in tokens if word not in thai_stopwords]

    # Removing non-Thai characters (optional, if mixed-language input)
    tokens = [word for word in tokens if all('\u0E00' <= char <= '\u0E7F' for char in word)]

    # Return the preprocessed text as a string of tokens
    return ' '.join(tokens)
