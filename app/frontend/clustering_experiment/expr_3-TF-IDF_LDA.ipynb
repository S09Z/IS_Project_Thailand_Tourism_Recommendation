# %%
import pandas as pd
import json
from pathlib import Path
import requests
import os
import glob

# %%
Merge_Attractions_df = pd.read_csv("./merged_tat_attractions.csv")

# %%
Merge_Attractions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4325 entries, 0 to 4324
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   placeId               4325 non-null   object
#  1   place_name_th         4324 non-null   object
#  2   introduction_th       2546 non-null   object
#  3   category_name         4325 non-null   object
#  4   categoryId            4325 non-null   int64
#  5   latitude              4313 non-null   float64
#  6   longitude             4313 non-null   float64
#  7   postcode              4215 non-null   float64
#  8   thumbnail_url         3601 non-null   object
#  9   tags                  857 non-null    object
#  10  province_Id           4325 non-null   int64
#  11  province_name_th      4325 non-null   object
#  12  district_Id           4317 non-null   float64
#  13  district_name_th      4317 non-null   object
#  14  sub_district_Id       4217 non-null   float64
#  15  sub_district_name_th  4217 non-null   object
#  16  updated_at            4325 non-null   object
#  17  introduction_en       1016 non-null   object
#  18  place_name_en         3919 non-null   object
#  19  province_name_en      4314 non-null   object
#  20  district_name_en      4306 non-null   object
#  21  sub_district_name_en  4206 non-null   object
# dtypes: float64(5), int64(2), object(15)
# memory usage: 743.5+ KB

# %%
len(Merge_Attractions_df)
# Out:
# 4325

# %%
all_tripadvisor_attractions_locations = pd.read_csv("data/tripadvisor_locations_avaiable.csv")

# %%
all_tripadvisor_attractions_locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1907 entries, 0 to 1906
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  1907 non-null   int64
#  1   Unnamed: 0    1907 non-null   int64
#  2   place_id      1907 non-null   object
#  3   location_id   1907 non-null   int64
#  4   name          1907 non-null   object
#  5   state         1149 non-null   object
#  6   country       1907 non-null   object
#  7   postalcode    1315 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 119.3+ KB

# %%
all_tripadvisor_attractions_locations = all_tripadvisor_attractions_locations.drop(
    columns=["Unnamed: 0.1", "Unnamed: 0"], errors="ignore"
)

# %%
all_tripadvisor_attractions_locations
# Out:
#        place_id  location_id                              name    state  \
# 0     P03003665       456633                    House of Opium  57150.0
# 1     P03003665     23933132                         Opium Bar      NaN
# 2     P03003590      7099963           Wat Phra That Doi Saket  50220.0
# 3     P03002324      1390125             Mae Ping River Cruise  50100.0
# 4     P03002324       547675                         Pai River      NaN
# ...         ...          ...                               ...      ...
# 1902  P03017171      8647002            Nang Lae Nai Waterfall      NaN
# 1903  P01000743     24105261        San Chao Rong Thong Market      NaN
# 1904  P03018527      8328708                         Cha's Bar      NaN
# 1905  P03018527     23208562  The Gundam Base Thailand Gallery      NaN
# 1906  P03018527     12902026                    Chao 9 Massage      NaN
#
#        country postalcode
# 0     Thailand    57150.0
# 1     Thailand    10100.0
# 2     Thailand    50220.0
# 3     Thailand    50100.0
# 4     Thailand        NaN
# ...        ...        ...
# 1902  Thailand        NaN
# 1903  Thailand        NaN
# 1904  Thailand    10200.0
# 1905  Thailand    10400.0
# 1906  Thailand    10330.0
#
# [1907 rows x 6 columns]

# %%
len(all_tripadvisor_attractions_locations)
# Out:
# 1907

# %%
combined_details_df = pd.read_csv("data/combined_details.csv")

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from gensim.models import Word2Vec
import numpy as np
import re


import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import string

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')


N_CLUSTER = 8
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/ittichaiboonyarakthunya/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/ittichaiboonyarakthunya/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/ittichaiboonyarakthunya/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from nltk.stem import WordNetLemmatizer

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %%
FINE_TUNED_DIR = '../../pretained_or_finetune-models'
REVIEWS_DATASET_DIR = '../../dataset'
UTILS_DIR = '../../utils'
NLTK_DATA_PATH = f"{FINE_TUNED_DIR}/nltk_data"

nltk.data.path.append(NLTK_DATA_PATH)

# %%
# รวมข้อความทั้งหมดจากคอลัมน์ 'tags'
all_text = " ".join(combined_details_df['tags'].fillna(''))

# สร้าง WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)

# แสดง WordCloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("WordCloud of All Tags")
plt.show()

# %% [markdown]
# ## Experiment - 1 [TF-IDF + K-MEAN + LDA]

# %%
# ตรวจสอบและแทนค่าที่เป็น NaN ในคอลัมน์ 'tags'
combined_details_df['tags'] = combined_details_df['tags'].fillna('')
combined_details_df['tags'].replace("", "other", inplace=True)

# แปลงข้อความใน 'tags' ให้เป็นเมทริกซ์ TF-IDF
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(combined_details_df['tags'])

# สร้างโมเดล LDA เพื่อหา topics
lda_model = LatentDirichletAllocation(n_components=N_CLUSTER, random_state=42)  # กำหนด 5 topics
lda_model.fit(X)

# ดึง top keywords ในแต่ละ topic
def print_topics(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic {topic_idx}:")
        print(" ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]))

print_topics(lda_model, vectorizer.get_feature_names_out(), n_top_words=10)

# กำหนดกลุ่มให้แต่ละสถานที่
combined_details_df['topic'] = lda_model.transform(X).argmax(axis=1)
# Out:
# /var/folders/fk/449tdf_12hzd2r7ps4659q0m0000gn/T/ipykernel_5980/2620588952.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_details_df['tags'].replace("", "other", inplace=True)
# Topic 0:
# historic monuments statues buildings gardens sites architectural ruins ancient neighborhoods
# Topic 1:
# beaches shops gift areas specialty wildlife nature lookouts bodies water
# Topic 2:
# spas malls shopping farms walking courses golf scenic adrenaline extreme
# Topic 3:
# parks museums tours specialty national boat scuba snorkeling nature wildlife
# Topic 4:
# interest points landmarks of mountains sports lookouts aquariums complexes cultural
# Topic 5:
# sacred religious sites waterfalls ferries forests sightseeing workshops lessons schools
# Topic 6:
# islands clubs museums bars history caverns caves art galleries bridges
# Topic 7:
# markets street flea farmers geologic formations churches cathedrals tubing rafting

# %%
perplexities = []
topic_range = range(2, 21)  # กำหนดช่วงของจำนวนหัวข้อ (2 ถึง 20)

for n_topics in topic_range:
    lda_model = LatentDirichletAllocation(n_components=n_topics, random_state=42)
    lda_model.fit(X)
    perplexities.append(lda_model.perplexity(X))

# การ Visualize ค่า Perplexity
plt.figure(figsize=(10, 6))
plt.plot(topic_range, perplexities, marker='o')
plt.title('LDA Perplexity vs Number of Topics')
plt.xlabel('Number of Topics')
plt.ylabel('Perplexity')
plt.xticks(topic_range)
plt.grid()
plt.show()

# %%
def get_topic_words(lda_model, feature_names, n_top_words=10):
    topic_words = []
    for topic_idx, topic in enumerate(lda_model.components_):
        words = [feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]]
        topic_words.append(" ".join(words))
    return topic_words

# Generate topic words from LDA model
topic_words = get_topic_words(lda_model, vectorizer.get_feature_names_out(), n_top_words=20)

# Function to plot WordClouds in a 2x2 grid
def plot_wordclouds_in_grid(topic_words, n_rows=2, n_cols=2):
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(12, 8))
    fig.suptitle("WordClouds for Topics", fontsize=16)
    
    for idx, words in enumerate(topic_words):
        if idx < n_rows * n_cols:
            row, col = divmod(idx, n_cols)
            wordcloud = WordCloud(width=800, height=400, background_color='white').generate(words)
            axes[row, col].imshow(wordcloud, interpolation='bilinear')
            axes[row, col].axis('off')
            axes[row, col].set_title(f"Topic {idx}", fontsize=12)
        else:
            axes[row, col].axis('off')  # Turn off any extra axes
    
    plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout to leave space for title
    plt.show()

# Plot the WordClouds in a 2x2 grid
plot_wordclouds_in_grid(topic_words, n_rows=4, n_cols=2)

# %%
combined_details_df[['name', 'tags', 'topic']]
# Out:
#                          name  \
# 0              House of Opium
# 1                   Opium Bar
# 2     Wat Phra That Doi Saket
# 3       Mae Ping River Cruise
# 4                   Pai River
# ...                       ...
# 1761           Chao Lao Beach
# 1762     Chao Lao Fish Bridge
# 1763        Wat Burapa Temple
# 1764         Kung Wiman Beach
# 1765  Scenic Kung Wiman beach
#
#                                                    tags  topic
# 0                    History Museums, Specialty Museums      6
# 1                                          Bars & Clubs      6
# 2                              Sacred & Religious Sites      5
# 3                                            Boat Tours      3
# 4                                       Bodies of Water      1
# ...                                                 ...    ...
# 1761                                            Beaches      1
# 1762                                            Bridges      6
# 1763  Sacred & Religious Sites, Architectural Buildings      0
# 1764                                            Beaches      1
# 1765                                           Lookouts      1
#
# [1766 rows x 3 columns]

# %%
def advanced_clean_text(text):
    text = text.lower()
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text = re.sub(r'[^a-z\s]', '', text)  # Remove special characters
    text = re.sub(r'\b(u|ur|b4)\b', 'you', text)  # Replace common abbreviations
    words = word_tokenize(text)
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]
    words = [word for word in words if word not in string.punctuation]
    return ' '.join(words)

# %%
combined_details_df = combined_details_df['tags'].replace("", "Other", inplace=True)

# %%
cleaned_details_df = combined_details_df['tags'].apply(advanced_clean_text)

cleaned_details_df
# Out:
# 0                    history museum specialty museum
# 1                                           bar club
# 2                              sacred religious site
# 3                                          boat tour
# 4                                         body water
#                             ...
# 1761                                           beach
# 1762                                          bridge
# 1763    sacred religious site architectural building
# 1764                                           beach
# 1765                                         lookout
# Name: tags, Length: 1766, dtype: object

# %%
# === Import Section ===
# Word embedding and clustering libraries
from gensim.models import Word2Vec
from sklearn.cluster import KMeans

# Data manipulation libraries
import numpy as np
import pandas as pd

# Visualization libraries
import matplotlib.pyplot as plt

# === Implementation ===

# Step 1: Train Word2Vec Model
# Tokenize sentences from your dataset
sentences = cleaned_details_df.apply(str.split).tolist()  # Tokenized sentences

# %%
sentences
# Out:
# [['history', 'museum', 'specialty', 'museum'],
#  ['bar', 'club'],
#  ['sacred', 'religious', 'site'],
#  ['boat', 'tour'],
#  ['body', 'water'],
#  ['point', 'interest', 'landmark', 'lookout'],
#  ['garden'],
#  ['point', 'interest', 'landmark'],
#  ['sightseeing', 'tour'],
#  ['hot', 'spring', 'geyser'],
#  ['national', 'park', 'park'],
#  ['flea', 'street', 'market'],
#  ['shopping', 'mall'],
#  ['specialty', 'museum'],
#  ['historic', 'site'],
#  ['historic', 'site', 'ancient', 'ruin'],
#  ['zoo'],
#  ['point', 'interest', 'landmark'],
#  ['performance'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['monument', 'statue'],
#  ['geologic', 'formation'],
#  ['specialty', 'museum'],
#  ['architectural', 'building'],
#  ['point', 'interest', 'landmark', 'sacred', 'religious', 'site'],
#  ['ancient', 'ruin'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['nature', 'wildlife', 'area'],
#  ['spa'],
#  ['zoo'],
#  ['point', 'interest', 'landmark'],
#  ['waterfall'],
#  ['farmer', 'market'],
#  ['natural', 'history', 'museum'],
#  ['point', 'interest', 'landmark'],
#  ['specialty', 'museum'],
#  ['shopping', 'mall'],
#  ['mass', 'transportation', 'system'],
#  ['farm'],
#  ['cavern', 'cave', 'nature', 'wildlife', 'area'],
#  ['historic', 'site', 'point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['flea', 'street', 'market'],
#  ['waterfall'],
#  ['scuba', 'snorkeling', 'adrenaline', 'extreme', 'tour'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark', 'sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['shopping', 'mall'],
#  ['national', 'park'],
#  ['point', 'interest', 'landmark'],
#  ['flea', 'street', 'market'],
#  ['theme', 'park', 'water', 'park'],
#  ['point', 'interest', 'landmark'],
#  ['beach'],
#  ['spa'],
#  ['waterfall'],
#  ['cooking', 'class'],
#  ['aquarium'],
#  ['island'],
#  ['cavern', 'cave'],
#  ['railway'],
#  ['neighborhood'],
#  ['flea', 'street', 'market'],
#  ['bar', 'club'],
#  ['neighborhood'],
#  ['history', 'museum'],
#  ['beach'],
#  ['shark', 'diving', 'scuba', 'snorkeling', 'boat', 'tour', 'water', 'sport'],
#  ['history', 'museum', 'specialty', 'museum'],
#  ['body', 'water'],
#  ['park'],
#  ['point', 'interest', 'landmark'],
#  ['art', 'gallery'],
#  ['cavern', 'cave', 'geologic', 'formation'],
#  ['beach'],
#  ['beach'],
#  ['scuba', 'snorkeling'],
#  ['scuba', 'snorkeling'],
#  ['beach'],
#  ['boat',
#   'tour',
#   'scuba',
#   'snorkeling',
#   'kayaking',
#   'canoeing',
#   'standup',
#   'paddleboarding',
#   'speed',
#   'boat',
#   'tour',
#   'eco',
#   'tour'],
#  ['beach'],
#  ['point', 'interest', 'landmark'],
#  ['geologic', 'formation'],
#  ['beach'],
#  ['sightseeing', 'tour'],
#  ['observation', 'deck', 'tower', 'lookout', 'point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['lookout'],
#  ['cavern', 'cave', 'nature', 'wildlife', 'area'],
#  ['farmer', 'market'],
#  ['park'],
#  ['history', 'museum'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark', 'sacred', 'religious', 'site'],
#  ['lookout'],
#  ['point', 'interest', 'landmark'],
#  ['history', 'museum'],
#  ['shopping', 'mall'],
#  ['sacred', 'religious', 'site'],
#  ['ancient', 'ruin', 'historic', 'site', 'point', 'interest', 'landmark'],
#  ['monument', 'statue'],
#  ['bar', 'club'],
#  ['point', 'interest', 'landmark'],
#  ['monument', 'statue'],
#  ['aquarium'],
#  ['flea', 'street', 'market'],
#  ['point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site'],
#  ['waterfall'],
#  ['point', 'interest', 'landmark'],
#  ['specialty', 'museum'],
#  ['beach'],
#  ['art', 'museum', 'history', 'museum'],
#  ['national', 'park'],
#  ['park', 'garden'],
#  ['golf', 'course'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark', 'monument', 'statue'],
#  ['waterfall'],
#  ['point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site', 'monument', 'statue'],
#  ['sacred', 'religious', 'site'],
#  ['scenic', 'walking', 'area', 'fountain'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['historic', 'site', 'point', 'interest', 'landmark'],
#  ['history', 'museum'],
#  ['sacred', 'religious', 'site'],
#  ['spa'],
#  ['sacred', 'religious', 'site'],
#  ['specialty', 'museum'],
#  ['beach'],
#  ['sacred', 'religious', 'site'],
#  ['nature', 'wildlife', 'area'],
#  ['spa'],
#  ['yoga', 'pilate'],
#  ['point', 'interest', 'landmark', 'sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['waterfall'],
#  ['flea', 'street', 'market'],
#  ['shopping', 'mall'],
#  ['beach'],
#  ['spa'],
#  ['point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site'],
#  ['spa'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark', 'farm'],
#  ['sacred', 'religious', 'site'],
#  ['nature', 'wildlife', 'tour'],
#  ['gift', 'specialty', 'shop'],
#  ['scenic', 'walking', 'area', 'lookout', 'point', 'interest', 'landmark'],
#  ['island'],
#  ['national', 'park'],
#  ['specialty', 'museum'],
#  ['sacred', 'religious', 'site'],
#  ['zoo'],
#  ['beach'],
#  ['geologic', 'formation'],
#  ['boat', 'tour', 'speed', 'boat', 'tour', 'boat', 'rental'],
#  ['flea', 'street', 'market'],
#  ['point', 'interest', 'landmark'],
#  ['flea', 'street', 'market'],
#  ['point', 'interest', 'landmark'],
#  ['gift', 'specialty', 'shop'],
#  ['flea', 'street', 'market'],
#  ['park'],
#  ['kayaking', 'canoeing', 'nature', 'wildlife', 'tour'],
#  ['boat',
#   'rental',
#   'beach',
#   'duck',
#   'tour',
#   'wd',
#   'atv',
#   'offroad',
#   'tour',
#   'fishing',
#   'charter',
#   'tour'],
#  ['nature', 'wildlife', 'tour', 'safari'],
#  ['historic', 'site', 'point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['historic', 'site'],
#  ['island'],
#  ['sacred', 'religious', 'site'],
#  ['visitor', 'center'],
#  ['gift', 'specialty', 'shop'],
#  ['gear', 'rental', 'scuba', 'snorkeling'],
#  ['healthfitness', 'club', 'gym'],
#  ['kayaking', 'canoeing', 'speed', 'boat', 'tour', 'gear', 'rental'],
#  ['cooking', 'class'],
#  ['spa'],
#  ['spa'],
#  ['waterfall'],
#  ['point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site', 'point', 'interest', 'landmark'],
#  ['monument', 'statue'],
#  ['gift', 'specialty', 'shop'],
#  ['hot', 'spring', 'geyser'],
#  ['sacred', 'religious', 'site'],
#  ['gift', 'specialty', 'shop'],
#  ['jazz', 'club', 'bar'],
#  ['gift', 'specialty', 'shop'],
#  ['scuba', 'snorkeling'],
#  ['water',
#   'sport',
#   'boat',
#   'tour',
#   'nature',
#   'wildlife',
#   'tour',
#   'scuba',
#   'snorkeling'],
#  ['lookout'],
#  ['lookout'],
#  ['spa'],
#  ['spa'],
#  ['boat', 'tour'],
#  ['body', 'water'],
#  ['gift', 'specialty', 'shop'],
#  ['cavern', 'cave'],
#  ['national', 'park'],
#  ['specialty', 'museum'],
#  ['cooking', 'class'],
#  ['shopping', 'mall'],
#  ['specialty', 'museum'],
#  ['point', 'interest', 'landmark', 'bridge'],
#  ['flea', 'street', 'market'],
#  ['nature', 'wildlife', 'area'],
#  ['park'],
#  ['gift', 'specialty', 'shop'],
#  ['private', 'tour'],
#  ['boat', 'tour'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['specialty', 'museum'],
#  ['beach', 'pool', 'club'],
#  ['performance'],
#  ['theme', 'park'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['spa'],
#  ['gift', 'specialty', 'shop'],
#  ['flea', 'street', 'market'],
#  ['gift', 'specialty', 'shop'],
#  ['spa', 'hair', 'nail', 'salon'],
#  ['sacred', 'religious', 'site'],
#  ['nature', 'wildlife', 'area'],
#  ['nature', 'wildlife', 'area'],
#  ['point', 'interest', 'landmark'],
#  ['taxi', 'shuttle'],
#  ['beach'],
#  ['scuba', 'snorkeling'],
#  ['gift', 'specialty', 'shop'],
#  ['waterfall'],
#  ['waterfall'],
#  ['water', 'sport', 'scuba', 'snorkeling', 'boat', 'tour'],
#  ['gift', 'specialty', 'shop'],
#  ['government', 'building'],
#  ['point', 'interest', 'landmark'],
#  ['historic',
#   'site',
#   'point',
#   'interest',
#   'landmark',
#   'military',
#   'base',
#   'facility'],
#  ['park'],
#  ['geologic', 'formation'],
#  ['dam'],
#  ['park'],
#  ['mountain'],
#  ['park', 'national', 'park'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['gift', 'specialty', 'shop'],
#  ['national', 'park', 'waterfall'],
#  ['beach'],
#  ['cavern', 'cave', 'nature', 'wildlife', 'area'],
#  ['cavern', 'cave'],
#  ['cavern', 'cave'],
#  ['point', 'interest', 'landmark'],
#  ['cavern', 'cave'],
#  ['flea', 'street', 'market'],
#  ['flea', 'street', 'market'],
#  ['point', 'interest', 'landmark'],
#  ['ancient',
#   'ruin',
#   'architectural',
#   'building',
#   'point',
#   'interest',
#   'landmark'],
#  ['flea', 'street', 'market'],
#  ['mountain'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['park'],
#  ['water', 'park'],
#  ['waterfall'],
#  ['waterfall'],
#  ['point', 'interest', 'landmark', 'sacred', 'religious', 'site'],
#  ['beach'],
#  ['specialty', 'museum'],
#  ['specialty', 'museum'],
#  ['national', 'park'],
#  ['point', 'interest', 'landmark'],
#  ['yoga', 'pilate'],
#  ['park', 'garden'],
#  ['point', 'interest', 'landmark'],
#  ['castle', 'point', 'interest', 'landmark', 'architectural', 'building'],
#  ['farmer', 'market'],
#  ['flea', 'street', 'market'],
#  ['flea', 'street', 'market'],
#  ['flea', 'street', 'market'],
#  ['sacred', 'religious', 'site', 'point', 'interest', 'landmark'],
#  ['shopping', 'mall'],
#  ['water', 'park'],
#  ['beach'],
#  ['aquarium'],
#  ['zoo'],
#  ['zoo'],
#  ['waterfall'],
#  ['waterfall'],
#  ['scenic', 'walking', 'area'],
#  ['hot', 'spring', 'geyser'],
#  ['nature', 'wildlife', 'area'],
#  ['nature', 'wildlife', 'area'],
#  ['nature', 'wildlife', 'area'],
#  ['nature', 'wildlife', 'tour'],
#  ['nature', 'wildlife', 'tour'],
#  ['nature', 'wildlife', 'area'],
#  ['historic', 'site', 'castle', 'architectural', 'building'],
#  ['art', 'gallery'],
#  ['beach'],
#  ['garden'],
#  ['hiking', 'camping', 'tour', 'nature', 'wildlife', 'tour'],
#  ['eco', 'tour', 'nature', 'wildlife', 'tour'],
#  ['wd', 'atv', 'offroad', 'tour'],
#  [],
#  [],
#  ['nature', 'wildlife', 'tour', 'hiking', 'camping', 'tour', 'eco', 'tour'],
#  [],
#  ['specialty', 'museum'],
#  ['monument', 'statue', 'point', 'interest', 'landmark'],
#  ['body', 'water'],
#  ['gift', 'specialty', 'shop'],
#  ['hiking', 'camping', 'tour'],
#  ['spa'],
#  ['park'],
#  ['national', 'park'],
#  ['specialty', 'museum'],
#  ['lookout', 'point', 'interest', 'landmark'],
#  ['specialty', 'museum', 'history', 'museum'],
#  ['nature', 'wildlife', 'tour'],
#  ['hiking', 'trail'],
#  ['specialty', 'museum'],
#  ['history', 'museum'],
#  ['specialty', 'museum'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark', 'sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['waterfall'],
#  ['shopping', 'mall'],
#  ['cultural', 'tour'],
#  ['sacred', 'religious', 'site'],
#  ['farm'],
#  ['gift', 'specialty', 'shop'],
#  ['sacred', 'religious', 'site', 'point', 'interest', 'landmark'],
#  ['park', 'national', 'park'],
#  ['sacred', 'religious', 'site'],
#  ['zipline', 'aerial', 'adventure', 'park'],
#  ['nature', 'wildlife', 'area'],
#  ['nature', 'wildlife', 'area'],
#  ['nature', 'wildlife', 'tour'],
#  ['nature', 'wildlife', 'area'],
#  ['nature', 'wildlife', 'area'],
#  ['nature', 'wildlife', 'area'],
#  ['nature', 'wildlife', 'area'],
#  ['nature', 'wildlife', 'tour'],
#  ['nature', 'wildlife', 'area'],
#  ['sacred', 'religious', 'site'],
#  ['garden', 'park'],
#  ['point', 'interest', 'landmark', 'lookout'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['waterfall'],
#  ['sacred', 'religious', 'site'],
#  ['shopping', 'mall', 'gift', 'specialty', 'shop'],
#  ['garden'],
#  ['garden'],
#  ['history', 'museum'],
#  ['flea', 'street', 'market'],
#  ['walking', 'tour', 'cultural', 'tour'],
#  ['thermal', 'spa'],
#  ['bar', 'club'],
#  ['sacred', 'religious', 'site'],
#  ['cavern', 'cave'],
#  ['point', 'interest', 'landmark', 'sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site', 'farm'],
#  ['flea', 'street', 'market'],
#  ['flea', 'street', 'market'],
#  ['flea', 'street', 'market'],
#  ['gift', 'specialty', 'shop'],
#  ['flea', 'street', 'market'],
#  ['nature', 'wildlife', 'area'],
#  ['waterfall'],
#  ['island'],
#  ['island'],
#  ['cavern', 'cave', 'island'],
#  ['farm'],
#  ['farm'],
#  ['sacred', 'religious', 'site'],
#  ['architectural', 'building', 'sacred', 'religious', 'site'],
#  ['gift', 'specialty', 'shop'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['farm'],
#  ['body', 'water'],
#  ['body', 'water'],
#  ['beach'],
#  ['historic', 'site', 'point', 'interest', 'landmark'],
#  ['body', 'water'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['national', 'park'],
#  ['waterfall'],
#  ['waterfall'],
#  ['shooting', 'range'],
#  ['body', 'water'],
#  ['nature', 'wildlife', 'tour'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['lookout'],
#  ['historic', 'site'],
#  ['healthfitness', 'club', 'gym', 'spa'],
#  ['specialty', 'museum'],
#  ['history', 'museum', 'military', 'museum'],
#  ['flea', 'street', 'market'],
#  ['monument', 'statue'],
#  ['park'],
#  ['sacred', 'religious', 'site'],
#  ['national', 'park', 'park'],
#  ['waterfall'],
#  ['body', 'water'],
#  ['point', 'interest', 'landmark'],
#  ['flea', 'street', 'market'],
#  ['waterfall'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['spa'],
#  ['spa'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site', 'historic', 'site'],
#  ['zoo'],
#  ['nature', 'wildlife', 'area'],
#  ['gift', 'specialty', 'shop'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['national', 'park'],
#  ['historic', 'site', 'point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site'],
#  ['educational', 'site'],
#  ['aquarium'],
#  ['specialty', 'museum'],
#  ['spa'],
#  ['spa'],
#  ['spa'],
#  ['spa'],
#  ['cooking', 'class'],
#  ['sacred', 'religious', 'site'],
#  ['flea', 'street', 'market'],
#  ['gear', 'rental'],
#  ['scuba', 'snorkeling'],
#  ['bar', 'club', 'pub', 'tour'],
#  ['arena', 'stadium'],
#  ['gift', 'specialty', 'shop'],
#  ['beach'],
#  ['historic', 'site'],
#  ['bar', 'club'],
#  ['gift', 'specialty', 'shop'],
#  ['monument', 'statue'],
#  ['bar', 'club'],
#  ['national', 'park'],
#  ['fishing',
#   'charter',
#   'tour',
#   'boat',
#   'tour',
#   'boat',
#   'rental',
#   'scuba',
#   'snorkeling'],
#  ['point', 'interest', 'landmark'],
#  ['beach'],
#  ['bar', 'club'],
#  ['island'],
#  ['island'],
#  ['point', 'interest', 'landmark'],
#  ['national', 'park'],
#  ['scuba', 'snorkeling', 'speed', 'boat', 'tour'],
#  ['beach'],
#  ['beach'],
#  ['island'],
#  ['university', 'school'],
#  ['scuba', 'snorkeling'],
#  ['boat', 'tour', 'nature', 'wildlife', 'tour', 'scuba', 'snorkeling'],
#  ['boat', 'tour', 'scuba', 'snorkeling', 'nature', 'wildlife', 'tour'],
#  ['safari', 'nature', 'wildlife', 'tour'],
#  ['nature', 'wildlife', 'tour'],
#  ['nature', 'wildlife', 'tour'],
#  ['eco', 'tour', 'nature', 'wildlife', 'tour'],
#  ['hiking', 'trail'],
#  ['nature', 'wildlife', 'tour'],
#  ['kayaking', 'canoeing', 'eco', 'tour'],
#  ['island'],
#  ['point', 'interest', 'landmark'],
#  ['climbing', 'tour'],
#  ['sacred', 'religious', 'site'],
#  ['nature', 'wildlife', 'tour', 'eco', 'tour'],
#  ['shopping', 'mall'],
#  ['flea', 'street', 'market'],
#  ['neighborhood'],
#  ['spa'],
#  ['sacred', 'religious', 'site'],
#  ['shopping', 'mall'],
#  ['speed',
#   'boat',
#   'tour',
#   'nature',
#   'wildlife',
#   'tour',
#   'kayaking',
#   'canoeing',
#   'hiking',
#   'camping',
#   'tour',
#   'river',
#   'rafting',
#   'tubing'],
#  ['nature', 'wildlife', 'tour'],
#  ['hiking', 'camping', 'tour', 'nature', 'wildlife', 'tour'],
#  ['point', 'interest', 'landmark'],
#  ['specialty', 'museum'],
#  ['beach'],
#  ['flea', 'street', 'market'],
#  ['sport', 'camp', 'clinic'],
#  ['lesson', 'workshop'],
#  ['water', 'sport'],
#  ['boat', 'tour'],
#  ['specialty', 'museum'],
#  ['park'],
#  ['beach'],
#  ['railway'],
#  ['eco', 'tour', 'hiking', 'camping', 'tour', 'nature', 'wildlife', 'tour'],
#  ['island'],
#  ['shopping', 'mall'],
#  ['sacred', 'religious', 'site'],
#  ['island'],
#  ['beach', 'pool', 'club'],
#  ['island'],
#  ['lookout', 'point', 'interest', 'landmark'],
#  ['beach'],
#  ['flea', 'street', 'market'],
#  ['beach'],
#  ['beach'],
#  ['nature', 'wildlife', 'area'],
#  ['nature', 'wildlife', 'area'],
#  ['point', 'interest', 'landmark', 'sacred', 'religious', 'site'],
#  ['monument', 'statue', 'sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site', 'point', 'interest', 'landmark', 'lookout'],
#  ['nature', 'wildlife', 'area'],
#  ['eco', 'tour', 'nature', 'wildlife', 'tour'],
#  ['eco', 'tour', 'nature', 'wildlife', 'tour'],
#  ['nature', 'wildlife', 'tour'],
#  ['lookout'],
#  ['dam'],
#  ['flea', 'street', 'market'],
#  ['hiking', 'trail'],
#  ['geologic', 'formation'],
#  ['sacred', 'religious', 'site'],
#  ['ferry'],
#  ['forest'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['flea', 'street', 'market'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site'],
#  ['art', 'museum'],
#  ['gift', 'specialty', 'shop'],
#  ['water', 'park'],
#  ['theater'],
#  ['observation',
#   'deck',
#   'tower',
#   'architectural',
#   'building',
#   'point',
#   'interest',
#   'landmark'],
#  ['shopping', 'mall'],
#  ['spa'],
#  ['game', 'entertainment', 'center'],
#  ['bar', 'club'],
#  ['day',
#   'trip',
#   'city',
#   'tour',
#   'private',
#   'tour',
#   'sightseeing',
#   'tour',
#   'cultural',
#   'tour'],
#  ['spa'],
#  ['neighborhood'],
#  ['cooking', 'class'],
#  ['spa'],
#  ['specialty', 'museum', 'science', 'museum'],
#  ['department', 'store', 'shopping', 'mall'],
#  ['flea', 'street', 'market'],
#  ['specialty', 'museum'],
#  ['castle',
#   'architectural',
#   'building',
#   'historic',
#   'site',
#   'educational',
#   'site'],
#  ['point', 'interest', 'landmark', 'sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['specialty', 'museum'],
#  ['flea', 'street', 'market'],
#  ['water', 'park'],
#  ['surfing',
#   'windsurfing',
#   'kitesurfing',
#   'gear',
#   'rental',
#   'standup',
#   'paddleboarding'],
#  ['spa'],
#  ['national', 'park', 'park', 'garden'],
#  ['specialty', 'museum'],
#  ['farmer', 'market'],
#  ['sacred', 'religious', 'site'],
#  ['food', 'tour'],
#  ['ferry'],
#  ['gear', 'rental'],
#  ['forest'],
#  ['spa'],
#  ['sacred', 'religious', 'site'],
#  ['flea', 'street', 'market'],
#  ['golf', 'course'],
#  ['cavern', 'cave'],
#  ['island'],
#  ['beach'],
#  ['beach'],
#  ['point', 'interest', 'landmark'],
#  ['beach'],
#  ['sacred', 'religious', 'site'],
#  ['mountain'],
#  ['lookout', 'point', 'interest', 'landmark'],
#  ['mountain', 'nature', 'wildlife', 'area'],
#  ['island'],
#  ['theme', 'park', 'water', 'park'],
#  ['beach'],
#  ['flea', 'street', 'market'],
#  ['river', 'rafting', 'tubing'],
#  ['sacred', 'religious', 'site', 'historic', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['gift', 'specialty', 'shop'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['sacred',
#   'religious',
#   'site',
#   'historic',
#   'site',
#   'point',
#   'interest',
#   'landmark'],
#  ['specialty', 'museum'],
#  ['national', 'park'],
#  ['specialty', 'museum'],
#  ['specialty', 'museum', 'history', 'museum'],
#  ['point', 'interest', 'landmark'],
#  ['history', 'museum'],
#  ['specialty', 'museum'],
#  ['historic', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['gift', 'specialty', 'shop'],
#  ['point', 'interest', 'landmark'],
#  ['spa'],
#  ['sport', 'camp', 'clinic'],
#  ['airport', 'lounge'],
#  ['gift', 'specialty', 'shop'],
#  ['national', 'park'],
#  ['cavern', 'cave'],
#  ['hot', 'spring', 'geyser'],
#  ['point',
#   'interest',
#   'landmark',
#   'architectural',
#   'building',
#   'sacred',
#   'religious',
#   'site'],
#  ['point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['bridge'],
#  ['sacred', 'religious', 'site'],
#  ['hiking', 'trail'],
#  ['point', 'interest', 'landmark', 'sacred', 'religious', 'site'],
#  ['lookout', 'point', 'interest', 'landmark', 'scenic', 'walking', 'area'],
#  ['sacred', 'religious', 'site', 'point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['theater'],
#  ['body', 'water'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site'],
#  ['aquarium'],
#  ['sacred', 'religious', 'site'],
#  ['historic', 'site', 'point', 'interest', 'landmark'],
#  ['architectural', 'building', 'historic', 'site', 'castle'],
#  ['historic',
#   'site',
#   'architectural',
#   'building',
#   'point',
#   'interest',
#   'landmark'],
#  ['garden'],
#  ['historic', 'site'],
#  ['historic',
#   'walking',
#   'area',
#   'historic',
#   'site',
#   'sacred',
#   'religious',
#   'site'],
#  ['gift', 'specialty', 'shop'],
#  ['sacred', 'religious', 'site', 'ancient', 'ruin'],
#  ['spa'],
#  ['sacred', 'religious', 'site'],
#  ['ferry'],
#  ['monument', 'statue'],
#  ['point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site', 'architectural', 'building'],
#  ['point', 'interest', 'landmark'],
#  ['gift', 'specialty', 'shop'],
#  ['flea', 'street', 'market'],
#  ['flea', 'street', 'market'],
#  ['flea', 'street', 'market'],
#  ['flea', 'street', 'market'],
#  ['monument', 'statue'],
#  ['church', 'cathedral'],
#  ['dam'],
#  ['marina'],
#  ['lookout'],
#  ['cavern', 'cave'],
#  ['hiking', 'trail'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark', 'sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['flea', 'street', 'market'],
#  ['canyoning',
#   'rappelling',
#   'tour',
#   'kayaking',
#   'canoeing',
#   'scuba',
#   'snorkeling',
#   'eco',
#   'tour',
#   'boat',
#   'tour',
#   'river',
#   'rafting',
#   'tubing',
#   'nature',
#   'wildlife',
#   'tour'],
#  ['sacred', 'religious', 'site'],
#  ['island'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['national', 'park', 'park'],
#  ['geologic', 'formation'],
#  ['nature', 'wildlife', 'area'],
#  ['mine'],
#  ['national', 'park', 'park'],
#  ['waterfall'],
#  ['selfguided', 'tour', 'rental'],
#  ['flea', 'street', 'market'],
#  ['golf', 'course'],
#  ['point', 'interest', 'landmark'],
#  ['mountain'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark', 'sacred', 'religious', 'site'],
#  ['geologic', 'formation'],
#  ['cavern', 'cave'],
#  ['gift', 'specialty', 'shop'],
#  ['flea', 'street', 'market'],
#  ['gift', 'specialty', 'shop'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site', 'point', 'interest', 'landmark'],
#  ['sport', 'complex'],
#  ['architectural', 'building', 'sacred', 'religious', 'site'],
#  ['golf', 'course'],
#  ['point', 'interest', 'landmark', 'lookout'],
#  ['specialty', 'museum'],
#  ['nature', 'wildlife', 'area'],
#  ['point', 'interest', 'landmark'],
#  ['adrenaline', 'extreme', 'tour'],
#  ['water', 'park'],
#  ['cooking', 'class'],
#  ['bar', 'club'],
#  ['historic', 'site', 'ancient', 'ruin', 'point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark', 'lookout'],
#  ['waterfall'],
#  ['point', 'interest', 'landmark'],
#  ['nature', 'wildlife', 'area'],
#  ['gift', 'specialty', 'shop'],
#  ['specialty', 'museum'],
#  ['church', 'cathedral'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['national', 'park'],
#  ['water', 'park', 'theme', 'park'],
#  ['flea', 'street', 'market', 'gift', 'specialty', 'shop'],
#  ['educational', 'site'],
#  ['natural', 'history', 'museum'],
#  ['science', 'museum'],
#  ['specialty', 'museum'],
#  ['point', 'interest', 'landmark'],
#  ['flea', 'street', 'market'],
#  ['gift', 'specialty', 'shop'],
#  ['flea', 'street', 'market'],
#  ['point', 'interest', 'landmark'],
#  ['shooting', 'range'],
#  ['point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark', 'sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['body', 'water'],
#  ['cooking', 'class'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['nature', 'wildlife', 'area'],
#  [],
#  ['eco', 'tour', 'nature', 'wildlife', 'tour', 'safari'],
#  ['nature', 'wildlife', 'tour'],
#  ['nature', 'wildlife', 'area'],
#  ['sport', 'camp', 'clinic'],
#  ['sport', 'camp', 'clinic'],
#  ['nature', 'wildlife', 'tour', 'hiking', 'trail'],
#  ['sacred', 'religious', 'site'],
#  ['river', 'rafting', 'tubing'],
#  ['sacred', 'religious', 'site', 'architectural', 'building'],
#  ['gear', 'rental'],
#  ['cooking', 'class'],
#  ['yoga', 'pilate'],
#  ['hot', 'spring', 'geyser'],
#  ['point', 'interest', 'landmark'],
#  ['hot', 'spring', 'geyser'],
#  ['lookout'],
#  ['flea', 'street', 'market'],
#  ['national', 'park'],
#  ['private',
#   'tour',
#   'sightseeing',
#   'tour',
#   'cultural',
#   'tour',
#   'city',
#   'tour'],
#  ['lookout'],
#  ['nature', 'wildlife', 'tour'],
#  ['wd',
#   'atv',
#   'offroad',
#   'tour',
#   'nature',
#   'wildlife',
#   'tour',
#   'adrenaline',
#   'extreme',
#   'tour'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['shopping', 'mall'],
#  ['farmer', 'market'],
#  ['gift', 'specialty', 'shop'],
#  ['beach'],
#  ['flea', 'street', 'market'],
#  ['lookout', 'sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site', 'point', 'interest', 'landmark'],
#  ['taxi', 'shuttle'],
#  ['body', 'water'],
#  ['gift', 'specialty', 'shop'],
#  ['ferry'],
#  ['cavern', 'cave'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['room', 'escape', 'game'],
#  ['spa'],
#  ['spa'],
#  ['point', 'interest', 'landmark'],
#  ['neighborhood'],
#  ['beach'],
#  ['beach'],
#  ['beach'],
#  ['nature', 'wildlife', 'area'],
#  ['body', 'water'],
#  ['game', 'entertainment', 'center'],
#  ['scenic', 'walking', 'area', 'lookout'],
#  ['point', 'interest', 'landmark', 'scenic', 'walking', 'area'],
#  ['body', 'water'],
#  ['waterfall'],
#  ['sacred', 'religious', 'site', 'point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site', 'point', 'interest', 'landmark'],
#  ['beach'],
#  ['ferry'],
#  ['bar', 'club'],
#  ['scuba', 'snorkeling'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site', 'point', 'interest', 'landmark'],
#  ['monument', 'statue', 'point', 'interest', 'landmark'],
#  ['park'],
#  ['specialty', 'museum'],
#  ['ferry'],
#  ['adrenaline', 'extreme', 'tour'],
#  ['boat', 'tour', 'scuba', 'snorkeling'],
#  ['eco',
#   'tour',
#   'scuba',
#   'snorkeling',
#   'speed',
#   'boat',
#   'tour',
#   'zipline',
#   'aerial',
#   'adventure',
#   'park',
#   'adrenaline',
#   'extreme',
#   'tour'],
#  ['art', 'gallery'],
#  ['taxi', 'shuttle'],
#  ['boat', 'rental'],
#  ['kayaking', 'canoeing'],
#  ['point', 'interest', 'landmark'],
#  ['hot', 'spring', 'geyser'],
#  ['sacred', 'religious', 'site', 'point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['waterfall', 'nature', 'wildlife', 'area'],
#  ['pier', 'boardwalk'],
#  ['scuba', 'snorkeling'],
#  ['point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site', 'point', 'interest', 'landmark'],
#  ['mountain', 'geologic', 'formation', 'cavern', 'cave'],
#  ['waterfall'],
#  ['specialty', 'museum'],
#  ['island'],
#  ['body', 'water'],
#  ['mountain'],
#  ['nature', 'wildlife', 'area'],
#  ['sacred', 'religious', 'site'],
#  ['farm'],
#  ['sacred', 'religious', 'site'],
#  ['scenic', 'drive'],
#  ['specialty', 'museum'],
#  ['sacred', 'religious', 'site'],
#  ['sacred', 'religious', 'site'],
#  ['gift', 'specialty', 'shop'],
#  ['spa'],
#  ['national', 'park'],
#  ['historic', 'walking', 'area'],
#  ['sacred', 'religious', 'site'],
#  ['ancient', 'ruin', 'historic', 'site', 'sacred', 'religious', 'site'],
#  ['farm'],
#  ['point', 'interest', 'landmark'],
#  ['historic', 'site'],
#  ['pier', 'boardwalk'],
#  ['ferry'],
#  ['beach'],
#  ['beach'],
#  ['neighborhood'],
#  ['art', 'museum'],
#  ['spa'],
#  ['bar', 'club'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['spa'],
#  ['spa'],
#  ['historic', 'site', 'architectural', 'building', 'government', 'building'],
#  ['point', 'interest', 'landmark'],
#  ['waterfall'],
#  ['national', 'park'],
#  ['waterfall'],
#  ['shopping', 'mall'],
#  ['spa'],
#  ['pier', 'boardwalk'],
#  ['spa'],
#  ['boat', 'tour'],
#  ['spa'],
#  ['farmer', 'market'],
#  ['point', 'interest', 'landmark'],
#  ['gift', 'specialty', 'shop'],
#  ['sacred', 'religious', 'site'],
#  ['thermal', 'spa', 'spa'],
#  ['spa'],
#  ['cooking', 'class'],
#  ['spa'],
#  ['flea', 'street', 'market'],
#  ['healthfitness', 'club', 'gym'],
#  ['sightseeing', 'tour'],
#  ['safari', 'nature', 'wildlife', 'tour'],
#  ['nature', 'wildlife', 'area'],
#  ['pier', 'boardwalk'],
#  ['cultural', 'tour'],
#  ['flea', 'street', 'market'],
#  ['nature', 'wildlife', 'area'],
#  ['boat',
#   'tour',
#   'eco',
#   'tour',
#   'boat',
#   'rental',
#   'bike',
#   'tour',
#   'gear',
#   'rental'],
#  ['bus', 'tour'],
#  ['church', 'cathedral'],
#  ['monument', 'statue'],
#  ['sport', 'camp', 'clinic'],
#  ['spa'],
#  ['nature', 'wildlife', 'area'],
#  ['forest'],
#  ['spa'],
#  ['point', 'interest', 'landmark'],
#  ['waterfall'],
#  ['bridge'],
#  ['boat', 'tour'],
#  ['point', 'interest', 'landmark'],
#  ['history', 'museum', 'specialty', 'museum'],
#  ['point', 'interest', 'landmark'],
#  ['point', 'interest', 'landmark'],
#  ['waterfall'],
#  ['forest', 'park'],
#  ['body', 'water'],
#  ['factory', 'outlet'],
#  ['winery', 'vineyard'],
#  ['sacred', 'religious', 'site'],
#  ['lookout'],
#  ['sacred', 'religious', 'site'],
#  ['point', 'interest', 'landmark'],
#  ['island'],
#  ['sacred', 'religious', 'site'],
#  ['park'],
#  ['auto', 'race', 'track'],
#  ['aquarium'],
#  ['point', 'interest', 'landmark'],
#  ['zoo'],
#  ['scuba', 'snorkeling', 'boat', 'tour'],
#  ['performance', 'theater'],
#  ['architectural', 'building', 'historic', 'site'],
#  ['swim', 'dolphin'],
#  ['flea', 'street', 'market'],
#  ['gift', 'specialty', 'shop'],
#  ['point', 'interest', 'landmark'],
#  ['performance'],
#  ['art', 'museum'],
#  ['theme', 'park'],
#  ['bar', 'club'],
#  ['specialty', 'museum'],
#  ['sacred', 'religious', 'site'],
#  ['boat',
#   'rental',
#   'fishing',
#   'charter',
#   'tour',
#   'boat',
#   'tour',
#   'speed',
#   'boat',
#   'tour',
#   'kayaking',
#   'canoeing',
#   'scuba',
#   'snorkeling'],
#  ['farm'],
#  ['specialty', 'museum'],
#  ['science', 'museum'],
#  ['movie', 'theater'],
#  ['bar', 'club'],
#  ['shopping', 'mall', 'factory', 'outlet'],
#  ['scuba',
#   'snorkeling',
#   'fishing',
#   'charter',
#   'tour',
#   'speed',
#   'boat',
#   'tour',
#   'boat',
#   'tour'],
#  ['garden'],
#  ['adrenaline', 'extreme', 'tour'],
#  ['adrenaline', 'extreme', 'tour'],
#  ['nature', 'wildlife', 'area'],
#  ['spa'],
#  ['nature', 'wildlife', 'area'],
#  ['adrenaline',
#   'extreme',
#   'tour',
#   'kayaking',
#   'canoeing',
#   'wd',
#   'atv',
#   'offroad',
#   'tour',
#   'air',
#   'tour',
#   'scuba',
#   'snorkeling'],
#  ['island'],
#  ['park'],
#  ['specialty', 'museum'],
#  ['game', 'entertainment', 'center'],
#  ['university', 'school'],
#  ['healthfitness', 'club', 'gym'],
#  ['architectural', 'building'],
#  ['farm'],
#  ['farm'],
#  ['canyon'],
#  ['canyon', 'geologic', 'formation'],
#  ['theme', 'park'],
#  ['aquarium'],
#  ['flea', 'street', 'market'],
#  ['performance'],
#  ['cabaret'],
#  ...]

# %%
# Train Word2Vec model
word2vec = Word2Vec(sentences, vector_size=300, window=100, min_count=1, workers=4)

# Extract word embeddings and corresponding words
word_vectors = word2vec.wv.vectors  # Word embeddings (array of shape [vocab_size, vector_size])
vocab = word2vec.wv.index_to_key  # List of words corresponding to the embeddings

# Step 2: Function to Cluster Words into Topics
def cluster_words(n_clusters):
    """
    Cluster word vectors using KMeans.
    :param n_clusters: Number of clusters/topics
    :return: KMeans model
    """
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(word_vectors)
    return kmeans

# Step 3: Compute Perplexity Approximation
def compute_perplexity(model, n_clusters):
    """
    Compute a perplexity-like score for the KMeans clustering.
    :param model: Fitted KMeans model
    :param n_clusters: Number of clusters/topics
    :return: Approximation of perplexity (lower is better)
    """
    distances = []
    for i, word in enumerate(vocab):
        word_vector = word_vectors[i]
        cluster_center = model.cluster_centers_[model.labels_[i]]
        distances.append(np.linalg.norm(word_vector - cluster_center))  # Euclidean distance

    avg_distance = np.mean(distances)  # Average distance as a perplexity approximation
    return avg_distance

# Step 4: Evaluate Perplexity for Multiple Numbers of Topics
n_topics_list = range(2, 21)  # Define the range of topic numbers to test
perplexity_scores = []

# Iterate over different numbers of topics
for n_topics in n_topics_list:
    kmeans_model = cluster_words(n_clusters=n_topics)
    perplexity = compute_perplexity(kmeans_model, n_clusters=n_topics)
    perplexity_scores.append(perplexity)

# Step 5: Plot Perplexity vs. Number of Topics
plt.figure(figsize=(10, 6))
plt.plot(n_topics_list, perplexity_scores, marker='o', label="Perplexity")
plt.xlabel('Number of Topics')
plt.ylabel('Perplexity (Approximation)')
plt.title('Perplexity vs Number of Topics (Word2Vec Clustering)')
plt.grid()
plt.legend()
plt.show()

# %%
from sklearn.cluster import KMeans
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Step 1: Cluster Words Using KMeans
def cluster_words(n_clusters, word_vectors):
    """
    Cluster word vectors using KMeans.
    :param n_clusters: Number of clusters/topics
    :param word_vectors: Word embeddings from Word2Vec
    :return: Fitted KMeans model
    """
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(word_vectors)
    return kmeans

# Step 2: Generate Word Clouds for Each Cluster
def generate_word_clouds(model, vocab, output_dir):
    """
    Generate and save word clouds for each cluster.
    :param model: Fitted KMeans model
    :param vocab: Vocabulary corresponding to the word vectors
    :param output_dir: Directory to save the word cloud images
    """
    for cluster_idx in range(model.n_clusters):
        # Aggregate words belonging to the current cluster
        cluster_words = [vocab[i] for i in range(len(vocab)) if model.labels_[i] == cluster_idx]
        cluster_word_str = " ".join(cluster_words)
        
        print(f"\nCluster {cluster_idx}:")
        print(", ".join(cluster_words[:10]))

        # Generate Word Cloud
        wordcloud = WordCloud(
            width=800,
            height=400,
            background_color="white",
            colormap="viridis"
        ).generate(cluster_word_str)

        # Save Word Cloud Image
        # output_path = f"{output_dir}/word_cloud_cluster_{cluster_idx}.png"
        # wordcloud.to_file(output_path)

        # Display Word Cloud
        # plt.figure(figsize=(10, 6))
        # plt.imshow(wordcloud, interpolation="bilinear")
        # plt.axis("off")
        # plt.title(f"Word Cloud for Cluster {cluster_idx}")
        # plt.show()

# %%
from sklearn.metrics.pairwise import cosine_similarity
cos_sim_matrix = cosine_similarity(word2vec.wv.vectors)

# %%
kmeans_model = cluster_words(n_clusters=20, word_vectors=word2vec.wv.vectors)

# %%
def compute_perplexity_cosine(kmeans_model, word_vectors):
    """
    Compute perplexity for KMeans clustering using cosine similarity on word embeddings.
    :param kmeans_model: Fitted KMeans model on word embeddings
    :param word_vectors: Word2Vec embeddings
    :return: Perplexity approximation (lower is better)
    """
    labels = kmeans_model.labels_
    cluster_centers = kmeans_model.cluster_centers_  # Cluster centers in the same space as word embeddings

    distances = []
    for i, label in enumerate(labels):
        word_vector = word_vectors[i]
        cluster_center = cluster_centers[label]
        
        # Cosine similarity between word vector and cluster center
        cos_sim = cosine_similarity(word_vector.reshape(1, -1), cluster_center.reshape(1, -1))[0][0]
        
        # Convert cosine similarity to distance
        cos_distance = 1 - cos_sim
        distances.append(cos_distance)

    # Average distance as perplexity approximation
    return np.mean(distances)

# %%
n_topics_range = range(2, 50)  # From 2 to 20 clusters
perplexity_scores = []

# Calculate perplexity for each number of clusters
for n_topics in n_topics_range:
    print(f"Clustering with {n_topics} topics...")
    kmeans_model = cluster_words(n_clusters=n_topics, word_vectors=word_vectors)
    perplexity = compute_perplexity_cosine(kmeans_model, word_vectors)
    perplexity_scores.append(perplexity)

# Plot perplexity vs. number of topics
plt.figure(figsize=(10, 6))
plt.plot(n_topics_range, perplexity_scores, marker='o', label='Perplexity')
plt.xlabel('Number of Topics')
plt.ylabel('Perplexity (Approximation)')
plt.title('Perplexity vs Number of Topics')
plt.grid()
plt.legend()
plt.show()
# Out:
# Clustering with 2 topics...
# Clustering with 3 topics...
# Clustering with 4 topics...
# Clustering with 5 topics...
# Clustering with 6 topics...
# Clustering with 7 topics...
# Clustering with 8 topics...
# Clustering with 9 topics...
# Clustering with 10 topics...
# Clustering with 11 topics...
# Clustering with 12 topics...
# Clustering with 13 topics...
# Clustering with 14 topics...
# Clustering with 15 topics...
# Clustering with 16 topics...
# Clustering with 17 topics...
# Clustering with 18 topics...
# Clustering with 19 topics...
# Clustering with 20 topics...
# Clustering with 21 topics...
# Clustering with 22 topics...
# Clustering with 23 topics...
# Clustering with 24 topics...
# Clustering with 25 topics...
# Clustering with 26 topics...
# Clustering with 27 topics...
# Clustering with 28 topics...
# Clustering with 29 topics...
# Clustering with 30 topics...
# Clustering with 31 topics...
# Clustering with 32 topics...
# Clustering with 33 topics...
# Clustering with 34 topics...
# Clustering with 35 topics...
# Clustering with 36 topics...
# Clustering with 37 topics...
# Clustering with 38 topics...
# Clustering with 39 topics...
# Clustering with 40 topics...
# Clustering with 41 topics...
# Clustering with 42 topics...
# Clustering with 43 topics...
# Clustering with 44 topics...
# Clustering with 45 topics...
# Clustering with 46 topics...
# Clustering with 47 topics...
# Clustering with 48 topics...
# Clustering with 49 topics...

# %%
kmeans_model = cluster_words(n_clusters=20, word_vectors=word_vectors)
perplexity = compute_perplexity_cosine(kmeans_model, word2vec.wv.vectors)
print(f"Perplexity (approximation): {perplexity}")
# Out:
# Perplexity (approximation): 0.40177417411045596

# %%
word2vec.wv.index_to_key
# Out:
# ['landmark',
#  'interest',
#  'point',
#  'site',
#  'sacred',
#  'religious',
#  'tour',
#  'specialty',
#  'museum',
#  'wildlife',
#  'nature',
#  'park',
#  'market',
#  'spa',
#  'flea',
#  'street',
#  'beach',
#  'area',
#  'shop',
#  'gift',
#  'boat',
#  'club',
#  'historic',
#  'waterfall',
#  'water',
#  'snorkeling',
#  'scuba',
#  'lookout',
#  'bar',
#  'building',
#  'national',
#  'mall',
#  'shopping',
#  'architectural',
#  'statue',
#  'monument',
#  'history',
#  'body',
#  'island',
#  'cave',
#  'cavern',
#  'farm',
#  'sport',
#  'hiking',
#  'ruin',
#  'ancient',
#  'eco',
#  'rental',
#  'art',
#  'cooking',
#  'class',
#  'garden',
#  'mountain',
#  'walking',
#  'farmer',
#  'scenic',
#  'theme',
#  'cultural',
#  'center',
#  'extreme',
#  'adrenaline',
#  'course',
#  'zoo',
#  'golf',
#  'trail',
#  'speed',
#  'bridge',
#  'canoeing',
#  'ferry',
#  'formation',
#  'kayaking',
#  'geologic',
#  'camping',
#  'shuttle',
#  'taxi',
#  'gear',
#  'game',
#  'spring',
#  'geyser',
#  'complex',
#  'charter',
#  'neighborhood',
#  'gallery',
#  'fishing',
#  'offroad',
#  'atv',
#  'wd',
#  'hot',
#  'aquarium',
#  'performance',
#  'entertainment',
#  'cathedral',
#  'sightseeing',
#  'church',
#  'disco',
#  'river',
#  'dance',
#  'rafting',
#  'tubing',
#  'pier',
#  'boardwalk',
#  'dam',
#  'forest',
#  'natural',
#  'camp',
#  'military',
#  'clinic',
#  'castle',
#  'gym',
#  'healthfitness',
#  'theater',
#  'safari',
#  'arena',
#  'stadium',
#  'private',
#  'event',
#  'educational',
#  'pilate',
#  'tower',
#  'deck',
#  'observation',
#  'track',
#  'workshop',
#  'yoga',
#  'science',
#  'race',
#  'auto',
#  'lesson',
#  'system',
#  'transportation',
#  'mass',
#  'drive',
#  'standup',
#  'jetskiing',
#  'playground',
#  'waterskiing',
#  'zipline',
#  'paddleboarding',
#  'school',
#  'adventure',
#  'thermal',
#  'facility',
#  'base',
#  'dolphin',
#  'range',
#  'bike',
#  'pool',
#  'city',
#  'university',
#  'visitor',
#  'shooting',
#  'cabaret',
#  'aerial',
#  'airport',
#  'department',
#  'store',
#  'swim',
#  'trip',
#  'government',
#  'day',
#  'canyon',
#  'factory',
#  'outlet',
#  'winery',
#  'movie',
#  'railway',
#  'vineyard',
#  'food',
#  'marina',
#  'biking',
#  'shark',
#  'paragliding',
#  'conference',
#  'convention',
#  'night',
#  'tramway',
#  'whale',
#  'watching',
#  'parasailing',
#  'balloon',
#  'bus',
#  'ride',
#  'state',
#  'brewery',
#  'horseback',
#  'riding',
#  'blue',
#  'valley',
#  'air',
#  'escape',
#  'diving',
#  'climbing',
#  'fountain',
#  'duck',
#  'jazz',
#  'coffeehouse',
#  'nail',
#  'salon',
#  'pub',
#  'surfing',
#  'room',
#  'windsurfing',
#  'kitesurfing',
#  'lounge',
#  'canyoning',
#  'rappelling',
#  'mine',
#  'selfguided',
#  'hair']

# %%
generate_word_clouds(kmeans_model, vocab=word2vec.wv.index_to_key, output_dir="./word_clouds")
# Out:
# Cluster 0:
# point, sacred, religious, specialty, market, street, bar, history, cave, cavern
#
# Cluster 1:
# spa, beach, waterfall, island, farm, garden, mountain, theme, bridge, ferry
#
# Cluster 2:
# tour
#
# Cluster 3:
# interest, site, museum, nature, park, area, historic, water, sport, ruin
#
# Cluster 4:
# wildlife, club, building, architectural, hiking, rental, walking, camping, river, rafting
#
# Cluster 5:
# farmer, zoo, neighborhood, performance, theater, arena, event, pilate, workshop, yoga
#
# Cluster 6:
# boat, snorkeling, scuba, eco, extreme, adrenaline, speed, canoeing, kayaking, charter
#
# Cluster 7:
# landmark, flea, shop, gift, lookout, national, mall, shopping, statue, monument
